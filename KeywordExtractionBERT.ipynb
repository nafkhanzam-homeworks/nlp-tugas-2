# %%
# !pip install pytorch-pretrained-bert
# Out:
# Requirement already satisfied: pytorch-pretrained-bert in /usr/local/lib/python3.7/dist-packages (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (4.63.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (1.21.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (2019.12.20)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (1.21.27)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.10.0.2)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert) (0.5.2)
# Requirement already satisfied: botocore<1.25.0,>=1.24.27 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert) (1.24.27)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert) (1.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.25.0,>=1.24.27->boto3->pytorch-pretrained-bert) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.25.0,>=1.24.27->boto3->pytorch-pretrained-bert) (1.25.11)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.27->boto3->pytorch-pretrained-bert) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert) (2.10)

# %%
import os
from tqdm import tqdm_notebook as tqdm
import numpy as np
import torch
import torch.nn as nn
from torch.utils import data
import torch.optim as optim
from pytorch_pretrained_bert import BertTokenizer

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
with open("/content/drive/MyDrive/smt 2/NLP/sequential labelling/dataset/train_preprocess.txt", 'r') as f:
    lines = f.readlines()

doc = []
sent = []
for e in lines:
    if e != "\n":
        split_sent = e.split("\t")
        label = split_sent[1].split("\n")[0]
        sent.append((split_sent[0], label))
    else:
        doc.append(sent)
        sent = []
doc.append(sent)

with open("/content/drive/MyDrive/smt 2/NLP/sequential labelling/dataset/valid_preprocess.txt", 'r') as f:
    lines = f.readlines()

validation_doc = []
sent = []
for e in lines:
    if e != "\n":
        split_sent = e.split("\t")
        label = split_sent[1].split("\n")[0]
        sent.append((split_sent[0], label))
    else:
        validation_doc.append(sent)
        sent = []
validation_doc.append(sent)

print(validation_doc[1])

with open("/content/drive/MyDrive/smt 2/NLP/sequential labelling/dataset/test_preprocess_masked_label.txt", 'r') as f:
    lines = f.readlines()

test_doc = []
sent = []
for e in lines:
    if e != "\n":
        split_sent = e.split("\t")
        label = split_sent[1].split("\n")[0]
        sent.append((split_sent[0], label))
    else:
        test_doc.append(sent)
        sent = []
test_doc.append(sent)
# Out:
# [('admin', 'O'), ('@halobca', 'B'), ('kok', 'O'), ('susah', 'B'), ('dihubungi', 'B'), ('ya', 'O'), ('apa', 'O'), ('sedang', 'O'), ('gangguan', 'B')]

# %%
tagged_sents = doc + validation_doc

# %%
tagged_sents[0]
# Out:
# [('Setelah', 'O'),
#  ('melalui', 'B'),
#  ('proses', 'B'),
#  ('telepon', 'I'),
#  ('yang', 'O'),
#  ('panjang', 'O'),
#  ('tutup', 'B'),
#  ('sudah', 'O'),
#  ('kartu', 'B'),
#  ('kredit', 'I'),
#  ('bca', 'I'),
#  ('Ribet', 'B')]

# %%
tags = list(set(word_pos[1] for sent in tagged_sents for word_pos in sent))
",".join(tags)
# Out:
# 'I,B,O'

# %%
# By convention, the 0'th slot is reserved for padding.
tags = ["<pad>"] + tags
tag2idx = {tag:idx for idx, tag in enumerate(tags)}
idx2tag = {idx:tag for idx, tag in enumerate(tags)}

# %%
# Let's split the data into train and test (or eval)
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(tagged_sents, test_size=.1)
len(train_data), len(test_data)
# Out:
# (900, 100)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
class PosDataset(data.Dataset):
    def __init__(self, tagged_sents):
        sents, tags_li = [], [] # list of lists
        for sent in tagged_sents:
            words = [word_pos[0] for word_pos in sent]
            tags = [word_pos[1] for word_pos in sent]
            sents.append(["[CLS]"] + words + ["[SEP]"])
            tags_li.append(["<pad>"] + tags + ["<pad>"])
        self.sents, self.tags_li = sents, tags_li

    def __len__(self):
        return len(self.sents)

    def __getitem__(self, idx):
        words, tags = self.sents[idx], self.tags_li[idx] # words, tags: string list

        # We give credits only to the first piece.
        x, y = [], [] # list of ids
        is_heads = [] # list. 1: the token is the first piece of a word
        for w, t in zip(words, tags):
            tokens = tokenizer.tokenize(w) if w not in ("[CLS]", "[SEP]") else [w]
            xx = tokenizer.convert_tokens_to_ids(tokens)

            is_head = [1] + [0]*(len(tokens) - 1)

            t = [t] + ["<pad>"] * (len(tokens) - 1)  # <PAD>: no decision
            yy = [tag2idx[each] for each in t]  # (T,)

            x.extend(xx)
            is_heads.extend(is_head)
            y.extend(yy)

        assert len(x)==len(y)==len(is_heads), "len(x)={}, len(y)={}, len(is_heads)={}".format(len(x), len(y), len(is_heads))

        # seqlen
        seqlen = len(y)

        # to string
        words = " ".join(words)
        tags = " ".join(tags)
        return words, x, is_heads, tags, y, seqlen

# %%
def pad(batch):
    '''Pads to the longest sample'''
    f = lambda x: [sample[x] for sample in batch]
    words = f(0)
    is_heads = f(2)
    tags = f(3)
    seqlens = f(-1)
    maxlen = np.array(seqlens).max()

    f = lambda x, seqlen: [sample[x] + [0] * (seqlen - len(sample[x])) for sample in batch] # 0: <pad>
    x = f(1, maxlen)
    y = f(-2, maxlen)


    f = torch.LongTensor

    return words, f(x), is_heads, tags, f(y), seqlens

# %%
from pytorch_pretrained_bert import BertModel

class Net(nn.Module):
    def __init__(self, vocab_size=None):
        super().__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        self.fc = nn.Linear(768, vocab_size)
        self.device = device

    def forward(self, x, y):
        '''
        x: (N, T). int64
        y: (N, T). int64
        '''
        x = x.to(device)
        y = y.to(device)
        
        if self.training:
            self.bert.train()
            encoded_layers, _ = self.bert(x)
            enc = encoded_layers[-1]
        else:
            self.bert.eval()
            with torch.no_grad():
                encoded_layers, _ = self.bert(x)
                enc = encoded_layers[-1]
        
        logits = self.fc(enc)
        y_hat = logits.argmax(-1)
        return logits, y, y_hat

# %%
def train(model, iterator, optimizer, criterion):
    model.train()
    for i, batch in enumerate(iterator):
        words, x, is_heads, tags, y, seqlens = batch
        _y = y # for monitoring
        optimizer.zero_grad()
        logits, y, _ = model(x, y) # logits: (N, T, VOCAB), y: (N, T)

        logits = logits.view(-1, logits.shape[-1]) # (N*T, VOCAB)
        y = y.view(-1)  # (N*T,)

        loss = criterion(logits, y)
        loss.backward()

        optimizer.step()

        if i%10==0: # monitoring
            print("step: {}, loss: {}".format(i, loss.item()))

# %%
def eval(model, iterator):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open("result", 'w') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write("{} {} {}\n".format(w, t, p))
            fout.write("\n")
            
    ## calc metric
    y_true =  np.array([tag2idx[line.split()[1]] for line in open('result', 'r').read().splitlines() if len(line) > 0])
    y_pred =  np.array([tag2idx[line.split()[2]] for line in open('result', 'r').read().splitlines() if len(line) > 0])

    acc = (y_true==y_pred).astype(np.int32).sum() / len(y_true)

    print("acc=%.2f"%acc)

# %%
model = Net(vocab_size=len(tag2idx))
model.to(device)
model = nn.DataParallel(model)
# Out:
# 100%|██████████| 407873900/407873900 [00:14<00:00, 27313125.54B/s]

# %%
train_dataset = PosDataset(train_data)
eval_dataset = PosDataset(test_data)

train_iter = data.DataLoader(dataset=train_dataset,
                             batch_size=8,
                             shuffle=True,
                             num_workers=1,
                             collate_fn=pad)
test_iter = data.DataLoader(dataset=eval_dataset,
                             batch_size=8,
                             shuffle=False,
                             num_workers=1,
                             collate_fn=pad)

optimizer = optim.Adam(model.parameters(), lr = 0.0001)

criterion = nn.CrossEntropyLoss(ignore_index=0)

# %%
train(model, train_iter, optimizer, criterion)
eval(model, test_iter)
# Out:
# step: 0, loss: 1.3086016178131104
# step: 10, loss: 0.9437406063079834
# step: 20, loss: 0.6064664125442505
# step: 30, loss: 0.6228988766670227
# step: 40, loss: 0.6202276349067688
# step: 50, loss: 0.6766679286956787
# step: 60, loss: 0.54524827003479
# step: 70, loss: 0.5278115272521973
# step: 80, loss: 0.5517987608909607
# step: 90, loss: 0.4807947278022766
# step: 100, loss: 0.5193215608596802
# step: 110, loss: 0.5195705890655518
# acc=0.80

# %%
test_data = test_doc
eval_dataset = PosDataset(test_data)
test_iter = data.DataLoader(dataset=eval_dataset,
                             batch_size=8,
                             shuffle=False,
                             num_workers=1,
                             collate_fn=pad)

train(model, train_iter, optimizer, criterion)
eval(model, test_iter)
# Out:
# step: 0, loss: 0.33176663517951965
# step: 10, loss: 0.3484683036804199
# step: 20, loss: 0.27326667308807373
# step: 30, loss: 0.18611134588718414
# step: 40, loss: 0.24255941808223724
# step: 50, loss: 0.2763305902481079
# step: 60, loss: 0.3419741690158844
# step: 70, loss: 0.32503655552864075
# step: 80, loss: 0.371150940656662
# step: 90, loss: 0.23849371075630188
# step: 100, loss: 0.18994107842445374
# step: 110, loss: 0.21894149482250214
# acc=0.58

# %%
with open("result.txt", 'r') as f:
    lines = f.readlines()

test_pred = []
sent = []
for e in lines:
    if e != "\n":
        split_sent = e.split(" ")
        label = split_sent[2].split("\n")[0]
        sent.append((split_sent[0], label))
    else:
        test_pred.append(sent)
        sent = []

# %%
i = 1
while True:
    print(i)
    print(test_doc[i])
    print(test_pred[i])
    if test_pred[i][0][0] != test_doc[i][0][0]:
        break
    i += 1
print(test_pred[i])
print(test_doc[i])
# Out:
# 1
# [('2', 'O'), ('minggu', 'O'), ('terakhir', 'O'), ('bolak', 'O'), ('balik', 'O'), ('kcp', 'O'), ('bca', 'O'), ('gegara', 'O'), ('isi', 'O'), ('flazz', 'O'), ('pakai', 'O'), ('atm', 'O'), ('sudah', 'O'), ('terdebit', 'O'), ('tetapi', 'O'), ('saldo', 'O'), ('flazz', 'O'), ('enggak', 'O'), ('menambah', 'O'), ('sampai', 'O'), ('sekarang', 'O'), ('belum', 'O'), ('kelar', 'O')]
# [('2', 'O'), ('minggu', 'O'), ('terakhir', 'O'), ('bolak', 'O'), ('balik', 'O'), ('kcp', 'I'), ('bca', 'I'), ('gegara', 'O'), ('isi', 'B'), ('flazz', 'B'), ('pakai', 'O'), ('atm', 'B'), ('sudah', 'O'), ('terdebit', 'O'), ('tetapi', 'O'), ('saldo', 'B'), ('flazz', 'B'), ('enggak', 'O'), ('menambah', 'B'), ('sampai', 'O'), ('sekarang', 'O'), ('belum', 'B'), ('kelar', 'I')]
# 2
# [('kok', 'O'), ('bisa-bisanya', 'O'), ('atm', 'O'), ('bca', 'O'), ('error', 'O'), ('sih', 'O'), ('saya', 'O'), ('sudah', 'O'), ('masukkan', 'O'), ('kartu', 'O'), ('terus', 'O'), ('atm-nya', 'O'), ('enggak', 'O'), ('jalan-jalan', 'O')]
# [('kok', 'O'), ('bisa-bisanya', 'O'), ('atm', 'B'), ('bca', 'I'), ('error', 'I'), ('sih', 'O'), ('saya', 'O'), ('sudah', 'O'), ('masukkan', 'B'), ('kartu', 'B'), ('terus', 'O'), ('atm-nya', 'O'), ('enggak', 'B'), ('jalan-jalan', 'I')]
# 3
# [('lebih', 'O'), ('baik', 'O'), ('jangan', 'O'), ('menukarkan', 'O'), ('ke', 'O'), ('atm', 'O'), ('bca', 'O'), ('yang', 'O'), ('baru', 'O'), ('kadang', 'O'), ('di', 'O'), ('tempat', 'O'), ('yang', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('menerima', 'O'), ('kartu', 'O'), ('kredit', 'O')]
# [('lebih', 'O'), ('baik', 'B'), ('jangan', 'O'), ('menukarkan', 'B'), ('ke', 'O'), ('atm', 'B'), ('bca', 'I'), ('yang', 'O'), ('baru', 'O'), ('kadang', 'O'), ('di', 'O'), ('tempat', 'O'), ('yang', 'O'), ('enggak', 'B'), ('bisa', 'O'), ('menerima', 'O'), ('kartu', 'B'), ('kredit', 'I')]
# 4
# [('ketika', 'O'), ('saya', 'O'), ('transfer', 'O'), ('menggunakan', 'O'), ('atm', 'O'), ('di', 'O'), ('cabang', 'O'), ('bca', 'O'), ('siliwangi', 'O'), ('setruk', 'O'), ('kertasnya', 'O'), ('tidak', 'O'), ('keluar', 'O'), ('sehingga', 'O'), ('saya', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('bukti', 'O'), ('transfer', 'O')]
# [('ketika', 'O'), ('saya', 'O'), ('transfer', 'B'), ('menggunakan', 'B'), ('atm', 'B'), ('di', 'O'), ('cabang', 'B'), ('bca', 'I'), ('siliwangi', 'O'), ('setruk', 'B'), ('kertasnya', 'B'), ('tidak', 'B'), ('keluar', 'I'), ('sehingga', 'O'), ('saya', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('bukti', 'B'), ('transfer', 'I')]
# 5
# [('mesin', 'O'), ('atm', 'O'), ('bca', 'O'), ('di', 'O'), ('alfamart', 'O'), ('palopo', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('membaca', 'O'), ('kartu', 'O'), ('atm', 'O'), ('saya', 'O'), ('lalu', 'O'), ('saya', 'O'), ('pindah', 'O'), ('ke', 'O'), ('atm', 'O'), ('cabang', 'O'), ('bca', 'O'), ('palopo', 'O'), ('ternyata', 'O'), ('atm', 'O'), ('saya', 'O'), ('tetap', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('terbaca', 'O'), ('bagaimana', 'O'), ('nih', 'O'), ('bca', 'O'), ('buruk', 'O'), ('banget', 'O'), ('fasilitas', 'O'), ('atm-nya', 'O')]
# [('mesin', 'B'), ('atm', 'B'), ('bca', 'I'), ('di', 'O'), ('alfamart', 'B'), ('palopo', 'O'), ('tidak', 'B'), ('bisa', 'O'), ('membaca', 'O'), ('kartu', 'B'), ('atm', 'I'), ('saya', 'O'), ('lalu', 'O'), ('saya', 'O'), ('pindah', 'B'), ('ke', 'O'), ('atm', 'B'), ('cabang', 'I'), ('bca', 'I'), ('palopo', 'O'), ('ternyata', 'O'), ('atm', 'O'), ('saya', 'O'), ('tetap', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('terbaca', 'O'), ('bagaimana', 'O'), ('nih', 'O'), ('bca', 'B'), ('buruk', 'B'), ('banget', 'O'), ('fasilitas', 'B'), ('atm-nya', 'B')]
# 6
# [('waktu', 'O'), ('itu', 'O'), ('saya', 'O'), ('ingin', 'O'), ('menarik', 'O'), ('uang', 'O'), ('melalui', 'O'), ('atm', 'O'), ('di', 'O'), ('bca', 'O'), ('ulak', 'O'), ('karang', 'O'), ('sebelumnya', 'O'), ('ada', 'O'), ('orang', 'O'), ('yang', 'O'), ('sudah', 'O'), ('tarik', 'O'), ('uang', 'O'), ('melalui', 'O'), ('atm', 'O'), ('dan', 'O'), ('berhasil', 'O'), ('tetapi', 'O'), ('pas', 'O'), ('tiba', 'O'), ('giliran', 'O'), ('saya', 'O'), ('mesinnya', 'O'), ('rusak', 'O'), ('dan', 'O'), ('atm', 'O'), ('saya', 'O'), ('tertelan', 'O'), ('di', 'O'), ('bca', 'O'), ('ulak', 'O'), ('karang', 'O'), ('dan', 'O'), ('kalau', 'O'), ('bisa', 'O'), ('di', 'O'), ('daerah', 'O'), ('ulak', 'O'), ('karang', 'O'), ('atm-nya', 'O'), ('diperbanyak', 'O'), ('juga', 'O'), ('percumalah', 'O'), ('bank', 'O'), ('besar', 'O'), ('kayak', 'O'), ('bca', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('menjangkau', 'O'), ('luas', 'O'), ('sampai', 'O'), ('ke', 'O'), ('daerah', 'O'), ('pedalaman', 'O')]
# [('waktu', 'O'), ('itu', 'O'), ('saya', 'O'), ('ingin', 'O'), ('menarik', 'B'), ('uang', 'B'), ('melalui', 'O'), ('atm', 'B'), ('di', 'O'), ('bca', 'B'), ('ulak', 'O'), ('karang', 'O'), ('sebelumnya', 'O'), ('ada', 'O'), ('orang', 'O'), ('yang', 'O'), ('sudah', 'O'), ('tarik', 'B'), ('uang', 'O'), ('melalui', 'O'), ('atm', 'B'), ('dan', 'O'), ('berhasil', 'B'), ('tetapi', 'O'), ('pas', 'O'), ('tiba', 'O'), ('giliran', 'O'), ('saya', 'O'), ('mesinnya', 'B'), ('rusak', 'B'), ('dan', 'O'), ('atm', 'O'), ('saya', 'O'), ('tertelan', 'B'), ('di', 'O'), ('bca', 'O'), ('ulak', 'O'), ('karang', 'O'), ('dan', 'O'), ('kalau', 'O'), ('bisa', 'O'), ('di', 'O'), ('daerah', 'O'), ('ulak', 'O'), ('karang', 'O'), ('atm-nya', 'O'), ('diperbanyak', 'B'), ('juga', 'O'), ('percumalah', 'B'), ('bank', 'B'), ('besar', 'O'), ('kayak', 'O'), ('bca', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('menjangkau', 'O'), ('luas', 'O'), ('sampai', 'O'), ('ke', 'O'), ('daerah', 'O'), ('pedalaman', 'B')]
# 7
# [('jadi', 'O'), ('waktu', 'O'), ('itu', 'O'), ('saya', 'O'), ('ingin', 'O'), ('menyetor', 'O'), ('uang', 'O'), ('melalui', 'O'), ('mesin', 'O'), ('setor', 'O'), ('tunai', 'O'), ('di', 'O'), ('bca', 'O'), ('jalan', 'O'), ('panglima', 'O'), ('polim', 'O'), ('banda', 'O'), ('aceh', 'O'), ('pada', 'O'), ('saat', 'O'), ('itu', 'O'), ('memang', 'O'), ('sedang', 'O'), ('libur', 'O'), ('panjang', 'O'), ('lalu', 'O'), ('ketika', 'O'), ('saya', 'O'), ('menyetor', 'O'), ('uang', 'O'), ('saya', 'O'), ('tersangkut', 'O'), ('di', 'O'), ('mesin', 'O'), ('sebanyak', 'O'), ('Rp700000000', 'O')]
# [('jadi', 'O'), ('waktu', 'O'), ('itu', 'O'), ('saya', 'O'), ('ingin', 'O'), ('menyetor', 'B'), ('uang', 'B'), ('melalui', 'O'), ('mesin', 'B'), ('setor', 'B'), ('tunai', 'I'), ('di', 'O'), ('bca', 'B'), ('jalan', 'O'), ('panglima', 'B'), ('polim', 'O'), ('banda', 'O'), ('aceh', 'O'), ('pada', 'O'), ('saat', 'O'), ('itu', 'O'), ('memang', 'O'), ('sedang', 'O'), ('libur', 'O'), ('panjang', 'O'), ('lalu', 'O'), ('ketika', 'O'), ('saya', 'O'), ('menyetor', 'B'), ('uang', 'O'), ('saya', 'O'), ('tersangkut', 'O'), ('di', 'O'), ('mesin', 'B'), ('sebanyak', 'O'), ('Rp700000000', 'O')]
# 8
# [('mesin', 'O'), ('setor', 'O'), ('tunainya', 'O'), ('terkadang', 'O'), ('error', 'O'), ('biasanya', 'O'), ('di', 'O'), ('jam', 'O'), ('8', 'O'), ('malam', 'O'), ('ke', 'O'), ('atas', 'O'), ('suka', 'O'), ('tidak', 'O'), ('dapat', 'O'), ('digunakan', 'O')]
# [('mesin', 'B'), ('setor', 'B'), ('tunainya', 'I'), ('terkadang', 'O'), ('error', 'B'), ('biasanya', 'O'), ('di', 'O'), ('jam', 'O'), ('8', 'O'), ('malam', 'O'), ('ke', 'O'), ('atas', 'O'), ('suka', 'O'), ('tidak', 'B'), ('dapat', 'I'), ('digunakan', 'I')]
# 9
# [('atm', 'O'), ('bca', 'O'), ('sukses', 'O'), ('banget', 'O'), ('menyusahkan', 'O'), ('hidup', 'O'), ('gue', 'O'), ('pagi', 'O'), ('ini', 'O'), ('di', 'O'), ('mal', 'O'), ('segede', 'O'), ('pim', 'O'), ('enggak', 'O'), ('ada', 'O'), ('juga', 'O')]
# [('atm', 'B'), ('bca', 'I'), ('sukses', 'B'), ('banget', 'O'), ('menyusahkan', 'B'), ('hidup', 'O'), ('gue', 'O'), ('pagi', 'O'), ('ini', 'O'), ('di', 'O'), ('mal', 'B'), ('segede', 'O'), ('pim', 'O'), ('enggak', 'O'), ('ada', 'O'), ('juga', 'O')]
# 10
# [('saya', 'O'), ('panik', 'O'), ('ketika', 'O'), ('setruk', 'O'), ('bukti', 'O'), ('transfer', 'O'), ('saya', 'O'), ('di', 'O'), ('atm', 'O'), ('mal', 'O'), ('kota', 'O'), ('kasablanka', 'O'), ('masnya', 'O'), ('datang', 'O'), ('dan', 'O'), ('bilang', 'O'), ('memang', 'O'), ('kertas', 'O'), ('setruknya', 'O'), ('habis', 'O')]
# [('saya', 'O'), ('panik', 'B'), ('ketika', 'O'), ('setruk', 'B'), ('bukti', 'B'), ('transfer', 'I'), ('saya', 'O'), ('di', 'O'), ('atm', 'B'), ('mal', 'I'), ('kota', 'I'), ('kasablanka', 'B'), ('masnya', 'O'), ('datang', 'O'), ('dan', 'O'), ('bilang', 'B'), ('memang', 'O'), ('kertas', 'B'), ('setruknya', 'O'), ('habis', 'O')]
# 11
# [('saya', 'O'), ('tidak', 'O'), ('suka', 'O'), ('atm', 'O'), ('bca', 'O'), ('karena', 'O'), ('pernah', 'O'), ('error', 'O'), ('saat', 'O'), ('saya', 'O'), ('dengan', 'O'), ('transaksi', 'O')]
# [('saya', 'O'), ('tidak', 'B'), ('suka', 'I'), ('atm', 'B'), ('bca', 'I'), ('karena', 'O'), ('pernah', 'B'), ('error', 'I'), ('saat', 'O'), ('saya', 'O'), ('dengan', 'O'), ('transaksi', 'B')]
# 12
# [('Sejak', 'O'), ('2', 'O'), ('hari', 'O'), ('yang', 'O'), ('lalu', 'O'), ('aplikasi', 'O'), ('bca', 'O'), ('mobile', 'O'), ('saya', 'O'), ('error', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('digunakan', 'O')]
# [('Sejak', 'O'), ('2', 'O'), ('hari', 'O'), ('yang', 'O'), ('lalu', 'O'), ('aplikasi', 'B'), ('bca', 'B'), ('mobile', 'I'), ('saya', 'O'), ('error', 'B'), ('tidak', 'B'), ('bisa', 'O'), ('digunakan', 'I')]
# 13
# [('duh', 'O'), ('pusing', 'O'), ('dari', 'O'), ('kemarin', 'O'), ('masalah', 'O'), ('melulu', 'O'), ('bca', 'O'), ('mobile', 'O'), ('saya', 'O'), ('jadi', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('belanja', 'O'), ('daring', 'O')]
# [('duh', 'O'), ('pusing', 'B'), ('dari', 'O'), ('kemarin', 'O'), ('masalah', 'B'), ('melulu', 'O'), ('bca', 'B'), ('mobile', 'I'), ('saya', 'O'), ('jadi', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('belanja', 'I'), ('daring', 'O')]
# 14
# [('kenapa', 'O'), ('saya', 'O'), ('tadi', 'O'), ('transfer', 'O'), ('uang', 'O'), ('pakai', 'O'), ('bca', 'O'), ('mobile', 'O'), ('tetapi', 'O'), ('dananya', 'O'), ('enggak', 'O'), ('terkirim', 'O')]
# [('kenapa', 'O'), ('saya', 'O'), ('tadi', 'O'), ('transfer', 'B'), ('uang', 'B'), ('pakai', 'O'), ('bca', 'B'), ('mobile', 'I'), ('tetapi', 'O'), ('dananya', 'B'), ('enggak', 'B'), ('terkirim', 'I')]
# 15
# [('kenapa', 'O'), ('saya', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('transfer', 'O'), ('dana', 'O'), ('ke', 'O'), ('bank', 'O'), ('lain', 'O'), ('dengan', 'O'), ('bca', 'O'), ('mobile', 'O'), ('admin', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('merepotkan', 'O'), ('tahu', 'O'), ('@halobca', 'O')]
# [('kenapa', 'O'), ('saya', 'O'), ('tidak', 'B'), ('bisa', 'I'), ('transfer', 'I'), ('dana', 'B'), ('ke', 'O'), ('bank', 'B'), ('lain', 'I'), ('dengan', 'O'), ('bca', 'B'), ('mobile', 'I'), ('admin', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('merepotkan', 'B'), ('tahu', 'O'), ('@halobca', 'B')]
# 16
# [('@halobca', 'O'), ('apakah', 'O'), ('m-banking', 'O'), ('dan', 'O'), ('aplikasi', 'O'), ('bca', 'O'), ('mobile', 'O'), ('sedang', 'O'), ('error', 'O'), ('mau', 'O'), ('transfer', 'O'), ('tidak', 'O'), ('bisa', 'O')]
# [('@halobca', 'B'), ('apakah', 'O'), ('m-banking', 'B'), ('dan', 'O'), ('aplikasi', 'B'), ('bca', 'B'), ('mobile', 'B'), ('sedang', 'O'), ('error', 'B'), ('mau', 'O'), ('transfer', 'B'), ('tidak', 'B'), ('bisa', 'O')]
# 17
# [('ini', 'O'), ('apa', 'O'), ('yang', 'O'), ('terjadi', 'O'), ('dengan', 'O'), ('bca', 'O'), ('mobile', 'O'), ('saya', 'O'), ('kok', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('dibuka', 'O'), ('dari', 'O'), ('kemarin', 'O')]
# [('ini', 'O'), ('apa', 'O'), ('yang', 'O'), ('terjadi', 'O'), ('dengan', 'O'), ('bca', 'B'), ('mobile', 'I'), ('saya', 'O'), ('kok', 'O'), ('tidak', 'B'), ('bisa', 'O'), ('dibuka', 'I'), ('dari', 'O'), ('kemarin', 'O')]
# 18
# [('selalu', 'O'), ('muncul', 'O'), ('notifikasi', 'O'), ('gagal', 'O'), ('di', 'O'), ('mobile', 'O'), ('bca', 'O'), ('sampai-sampai', 'O'), ('saya', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('transaksi', 'O')]
# [('selalu', 'O'), ('muncul', 'O'), ('notifikasi', 'B'), ('gagal', 'B'), ('di', 'O'), ('mobile', 'B'), ('bca', 'I'), ('sampai-sampai', 'O'), ('saya', 'O'), ('tidak', 'B'), ('bisa', 'O'), ('transaksi', 'B')]
# 19
# [('memang', 'O'), ('bca', 'O'), ('mobile', 'O'), ('ini', 'O'), ('masalah', 'O'), ('terus', 'O'), ('beda', 'O'), ('sama', 'O'), ('mandiri', 'O'), ('mobile', 'O')]
# [('memang', 'O'), ('bca', 'B'), ('mobile', 'I'), ('ini', 'O'), ('masalah', 'B'), ('terus', 'O'), ('beda', 'O'), ('sama', 'O'), ('mandiri', 'B'), ('mobile', 'O')]
# 20
# [('bca', 'O'), ('mobile', 'O'), ('saya', 'O'), ('sudah', 'O'), ('berbulan-bulan', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('digunakan', 'O'), ('gara-gara', 'O'), ('error', 'O'), ('waktu', 'O'), ('itu', 'O')]
# [('bca', 'B'), ('mobile', 'I'), ('saya', 'O'), ('sudah', 'O'), ('berbulan-bulan', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('digunakan', 'I'), ('gara-gara', 'O'), ('error', 'B'), ('waktu', 'O'), ('itu', 'O')]
# 21
# [('saya', 'O'), ('kemarin', 'O'), ('buat', 'O'), ('rekening', 'O'), ('baru', 'O'), ('di', 'O'), ('bca', 'O'), ('dan', 'O'), ('dibuatkan', 'O'), ('bca', 'O'), ('mobile', 'O'), ('tetapi', 'O'), ('sampai', 'O'), ('saat', 'O'), ('ini', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('digunakan', 'O'), ('dengan', 'O'), ('notifikasi', 'O'), ('aneh', 'O')]
# [('saya', 'O'), ('kemarin', 'O'), ('buat', 'O'), ('rekening', 'B'), ('baru', 'O'), ('di', 'O'), ('bca', 'B'), ('dan', 'O'), ('dibuatkan', 'B'), ('bca', 'O'), ('mobile', 'I'), ('tetapi', 'O'), ('sampai', 'O'), ('saat', 'O'), ('ini', 'O'), ('tidak', 'B'), ('bisa', 'I'), ('digunakan', 'I'), ('dengan', 'O'), ('notifikasi', 'B'), ('aneh', 'O')]
# 22
# [('kak', 'O'), ('cara', 'O'), ('bayar', 'O'), ('tiket', 'O'), ('kereta', 'O'), ('api', 'O'), ('melalui', 'O'), ('aplikasi', 'O'), ('mobile', 'O'), ('bca', 'O'), ('bagaimana', 'O')]
# [('kak', 'O'), ('cara', 'B'), ('bayar', 'B'), ('tiket', 'I'), ('kereta', 'I'), ('api', 'I'), ('melalui', 'O'), ('aplikasi', 'B'), ('mobile', 'B'), ('bca', 'I'), ('bagaimana', 'O')]
# 23
# [('untung', 'O'), ('banget', 'O'), ('deh', 'O'), ('memasang', 'O'), ('bca', 'O'), ('mobile', 'O'), ('semua', 'O'), ('transaksi', 'O'), ('daring', 'O'), ('dapat', 'O'), ('dilakukan', 'O'), ('dengan', 'O'), ('mudah', 'O')]
# [('untung', 'O'), ('banget', 'O'), ('deh', 'O'), ('memasang', 'B'), ('bca', 'B'), ('mobile', 'O'), ('semua', 'O'), ('transaksi', 'B'), ('daring', 'B'), ('dapat', 'O'), ('dilakukan', 'B'), ('dengan', 'O'), ('mudah', 'B')]
# 24
# [('pembayaran', 'O'), ('di', 'O'), ('marketplace', 'O'), ('lain', 'O'), ('juga', 'O'), ('bisa', 'O'), ('pakai', 'O'), ('bca', 'O'), ('mobile', 'O'), ('tidak', 'O'), ('ya', 'O'), ('@halobca', 'O')]
# [('pembayaran', 'B'), ('di', 'O'), ('marketplace', 'B'), ('lain', 'O'), ('juga', 'O'), ('bisa', 'O'), ('pakai', 'O'), ('bca', 'B'), ('mobile', 'I'), ('tidak', 'O'), ('ya', 'O'), ('@halobca', 'B')]
# 25
# [('transaksi', 'O'), ('menggunakan', 'O'), ('bca', 'O'), ('mobile', 'O'), ('dapat', 'O'), ('menggunakan', 'O'), ('m-bca', 'O'), ('dan', 'O'), ('klikbca', 'O')]
# [('transaksi', 'B'), ('menggunakan', 'B'), ('bca', 'B'), ('mobile', 'I'), ('dapat', 'O'), ('menggunakan', 'B'), ('m-bca', 'B'), ('dan', 'O'), ('klikbca', 'B')]
# 26
# [('bayar-bayar', 'O'), ('segala', 'O'), ('transaksi', 'O'), ('memang', 'O'), ('pakai', 'O'), ('bca', 'O'), ('mobile', 'O'), ('sudah', 'O'), ('paling', 'O'), ('oke', 'O')]
# [('bayar-bayar', 'B'), ('segala', 'O'), ('transaksi', 'B'), ('memang', 'O'), ('pakai', 'O'), ('bca', 'B'), ('mobile', 'I'), ('sudah', 'O'), ('paling', 'O'), ('oke', 'B')]
# 27
# [('aplikasi', 'O'), ('bca', 'O'), ('mobile', 'O'), ('gampang', 'O'), ('banget', 'O'), ('dipelajari', 'O'), ('pemakaiannya', 'O')]
# [('aplikasi', 'B'), ('bca', 'B'), ('mobile', 'I'), ('gampang', 'B'), ('banget', 'O'), ('dipelajari', 'B'), ('pemakaiannya', 'B')]
# 28
# [('@kai121', 'O'), ('cara', 'O'), ('bayar', 'O'), ('tiket', 'O'), ('lewat', 'O'), ('bca', 'O'), ('mobile', 'O'), ('bagaimana', 'O'), ('ya', 'O'), ('terima', 'O'), ('kasih', 'O')]
# [('@kai121', 'B'), ('cara', 'B'), ('bayar', 'B'), ('tiket', 'I'), ('lewat', 'O'), ('bca', 'B'), ('mobile', 'I'), ('bagaimana', 'O'), ('ya', 'O'), ('terima', 'O'), ('kasih', 'O')]
# 29
# [('sudah', 'O'), ('berjuta-juta', 'O'), ('kali', 'O'), ('saya', 'O'), ('coba', 'O'), ('akses', 'O'), ('tetapi', 'O'), ('masih', 'O'), ('tetap', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('digunakan', 'O'), ('aplikasi', 'O'), ('bca', 'O'), ('mobile', 'O'), ('ini', 'O')]
# [('sudah', 'O'), ('berjuta-juta', 'O'), ('kali', 'O'), ('saya', 'O'), ('coba', 'O'), ('akses', 'B'), ('tetapi', 'O'), ('masih', 'O'), ('tetap', 'O'), ('tidak', 'B'), ('bisa', 'O'), ('digunakan', 'I'), ('aplikasi', 'B'), ('bca', 'B'), ('mobile', 'O'), ('ini', 'O')]
# 30
# [('kemarin', 'O'), ('saya', 'O'), ('bayar', 'O'), ('transaksi', 'O'), ('di', 'O'), ('bukalapak', 'O'), ('pakai', 'O'), ('aplikasi', 'O'), ('bca', 'O'), ('mobile', 'O'), ('yang', 'O'), ('baru', 'O'), ('saya', 'O'), ('pasang', 'O')]
# [('kemarin', 'O'), ('saya', 'O'), ('bayar', 'B'), ('transaksi', 'B'), ('di', 'O'), ('bukalapak', 'O'), ('pakai', 'O'), ('aplikasi', 'B'), ('bca', 'B'), ('mobile', 'I'), ('yang', 'O'), ('baru', 'O'), ('saya', 'O'), ('pasang', 'B')]
# 31
# [('@telkomsel', 'O'), ('cara', 'O'), ('beli', 'O'), ('pulsa', 'O'), ('lewat', 'O'), ('bca', 'O'), ('mobile', 'O'), ('bagaimana', 'O'), ('ya', 'O'), ('terima', 'O'), ('kasih', 'O')]
# [('@telkomsel', 'B'), ('cara', 'B'), ('beli', 'B'), ('pulsa', 'I'), ('lewat', 'O'), ('bca', 'B'), ('mobile', 'I'), ('bagaimana', 'O'), ('ya', 'O'), ('terima', 'O'), ('kasih', 'O')]
# 32
# [('@tokopedia', 'O'), ('cara', 'O'), ('bayar', 'O'), ('trasnaksi', 'O'), ('lewat', 'O'), ('bca', 'O'), ('mobile', 'O'), ('bagaimana', 'O'), ('ya', 'O'), ('terima', 'O'), ('kasih', 'O')]
# [('@tokopedia', 'B'), ('cara', 'B'), ('bayar', 'B'), ('trasnaksi', 'B'), ('lewat', 'O'), ('bca', 'B'), ('mobile', 'I'), ('bagaimana', 'O'), ('ya', 'O'), ('terima', 'O'), ('kasih', 'O')]
# 33
# [('apa', 'O'), ('sih', 'O'), ('yang', 'O'), ('dimaksud', 'O'), ('dengan', 'O'), ('e-channel', 'O'), ('bca', 'O')]
# [('apa', 'O'), ('sih', 'O'), ('yang', 'O'), ('dimaksud', 'B'), ('dengan', 'O'), ('e-channel', 'B'), ('bca', 'I')]
# 34
# [('fasilitas', 'O'), ('apa', 'O'), ('saja', 'O'), ('yang', 'O'), ('diberikan', 'O'), ('oleh', 'O'), ('bca', 'O'), ('dalam', 'O'), ('e-channel', 'O'), ('tersebut', 'O'), ('@halobca', 'O')]
# [('fasilitas', 'B'), ('apa', 'O'), ('saja', 'O'), ('yang', 'O'), ('diberikan', 'O'), ('oleh', 'O'), ('bca', 'B'), ('dalam', 'O'), ('e-channel', 'B'), ('tersebut', 'O'), ('@halobca', 'B')]
# 35
# [('banyak', 'O'), ('sekali', 'O'), ('jenis', 'O'), ('fasilitas', 'O'), ('yang', 'O'), ('diberikan', 'O'), ('oleh', 'O'), ('bank', 'O'), ('lain', 'O'), ('secara', 'O'), ('keseluruhan', 'O'), ('saya', 'O'), ('lebih', 'O'), ('suka', 'O'), ('fasilitas', 'O'), ('bca', 'O'), ('e-channel', 'O')]
# [('banyak', 'O'), ('sekali', 'O'), ('jenis', 'O'), ('fasilitas', 'B'), ('yang', 'O'), ('diberikan', 'O'), ('oleh', 'O'), ('bank', 'B'), ('lain', 'I'), ('secara', 'O'), ('keseluruhan', 'B'), ('saya', 'O'), ('lebih', 'O'), ('suka', 'O'), ('fasilitas', 'B'), ('bca', 'I'), ('e-channel', 'B')]
# 36
# [('atm', 'O'), ('dan', 'O'), ('klikbca', 'O'), ('adalah', 'O'), ('dua', 'O'), ('hal', 'O'), ('yang', 'O'), ('berbeda', 'O'), ('tetapi', 'O'), ('mempunyai', 'O'), ('fungsi', 'O'), ('yang', 'O'), ('sama:', 'O'), ('memudahkan', 'O')]
# [('atm', 'B'), ('dan', 'O'), ('klikbca', 'B'), ('adalah', 'O'), ('dua', 'O'), ('hal', 'O'), ('yang', 'O'), ('berbeda', 'B'), ('tetapi', 'O'), ('mempunyai', 'B'), ('fungsi', 'B'), ('yang', 'O'), ('sama:', 'O'), ('memudahkan', 'B')]
# 37
# [('saya', 'O'), ('bangga', 'O'), ('sih', 'O'), ('pakai', 'O'), ('klikbca', 'O'), ('dan', 'O'), ('bca', 'O'), ('mobile', 'O'), ('untuk', 'O'), ('kebutuhan', 'O'), ('sehari-hari', 'O')]
# [('saya', 'O'), ('bangga', 'O'), ('sih', 'O'), ('pakai', 'O'), ('klikbca', 'B'), ('dan', 'O'), ('bca', 'B'), ('mobile', 'I'), ('untuk', 'O'), ('kebutuhan', 'B'), ('sehari-hari', 'O')]
# 38
# [('keren', 'O'), ('e-channel', 'O'), ('bca', 'O')]
# [('keren', 'B'), ('e-channel', 'B'), ('bca', 'I')]
# 39
# [('tolong', 'O'), ('tampilan', 'O'), ('m-banking', 'O'), ('internet', 'O'), ('banking', 'O'), ('dll', 'O'), ('juga', 'O'), ('dong', 'O'), ('biar', 'O'), ('lebih', 'O'), ('kekinian', 'O'), ('dan', 'O'), ('modern', 'O'), ('begitu', 'O'), ('pula', 'O'), ('dengan', 'O'), ('tampilan', 'O'), ('kartu', 'O'), ('kreditnya', 'O')]
# [('tolong', 'O'), ('tampilan', 'B'), ('m-banking', 'B'), ('internet', 'B'), ('banking', 'I'), ('dll', 'B'), ('juga', 'O'), ('dong', 'O'), ('biar', 'O'), ('lebih', 'O'), ('kekinian', 'O'), ('dan', 'O'), ('modern', 'B'), ('begitu', 'O'), ('pula', 'O'), ('dengan', 'O'), ('tampilan', 'O'), ('kartu', 'B'), ('kreditnya', 'I')]
# 40
# [('sebagai', 'O'), ('saran', 'O'), ('bukan', 'O'), ('hanya', 'O'), ('tampilan', 'O'), ('paspor', 'O'), ('saja', 'O'), ('yang', 'O'), ('diperbarui', 'O'), ('dengan', 'O'), ('tampilan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('modern', 'O'), ('tetapi', 'O'), ('tampilan', 'O'), ('internet', 'O'), ('banking', 'O'), ('bca', 'O'), ('mobile', 'O'), ('dll', 'O'), ('juga', 'O'), ('diperbarui', 'O'), ('dengan', 'O'), ('tampilan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('modern', 'O'), ('agar', 'O'), ('pengguna', 'O'), ('tidak', 'O'), ('bosan', 'O'), ('dengan', 'O'), ('tampilan', 'O'), ('sekarang', 'O'), ('saran', 'O'), ('saja', 'O'), ('sih', 'O'), ('hehe', 'O')]
# [('sebagai', 'O'), ('saran', 'O'), ('bukan', 'O'), ('hanya', 'O'), ('tampilan', 'B'), ('paspor', 'B'), ('saja', 'O'), ('yang', 'O'), ('diperbarui', 'B'), ('dengan', 'O'), ('tampilan', 'B'), ('yang', 'O'), ('lebih', 'O'), ('modern', 'O'), ('tetapi', 'O'), ('tampilan', 'B'), ('internet', 'B'), ('banking', 'I'), ('bca', 'B'), ('mobile', 'O'), ('dll', 'O'), ('juga', 'O'), ('diperbarui', 'B'), ('dengan', 'O'), ('tampilan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('modern', 'O'), ('agar', 'O'), ('pengguna', 'B'), ('tidak', 'O'), ('bosan', 'O'), ('dengan', 'O'), ('tampilan', 'O'), ('sekarang', 'O'), ('saran', 'O'), ('saja', 'O'), ('sih', 'O'), ('hehe', 'O')]
# 41
# [('daftar', 'O'), ('channel', 'O'), ('tidak', 'O'), ('harus', 'O'), ('ke', 'O'), ('cabang', 'O'), ('bca', 'O'), ('terdekat', 'O'), ('prosesnya', 'O'), ('mempermudah', 'O'), ('nasabah', 'O')]
# [('daftar', 'B'), ('channel', 'I'), ('tidak', 'B'), ('harus', 'O'), ('ke', 'O'), ('cabang', 'B'), ('bca', 'I'), ('terdekat', 'O'), ('prosesnya', 'B'), ('mempermudah', 'B'), ('nasabah', 'B')]
# 42
# [('E-channel', 'O'), ('harus', 'O'), ('lebih', 'O'), ('canggih', 'O'), ('biar', 'O'), ('makin', 'O'), ('keren', 'O'), ('bca', 'O')]
# [('E-channel', 'B'), ('harus', 'O'), ('lebih', 'O'), ('canggih', 'B'), ('biar', 'O'), ('makin', 'O'), ('keren', 'B'), ('bca', 'B')]
# 43
# [('tidak', 'O'), ('perlu', 'O'), ('risau', 'O'), ('kalau', 'O'), ('sudah', 'O'), ('ada', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('semua', 'O'), ('transaksi', 'O'), ('aman', 'O'), ('terkendali', 'O')]
# [('tidak', 'B'), ('perlu', 'O'), ('risau', 'O'), ('kalau', 'O'), ('sudah', 'O'), ('ada', 'O'), ('e-channel', 'B'), ('bca', 'I'), ('semua', 'O'), ('transaksi', 'B'), ('aman', 'B'), ('terkendali', 'B')]
# 44
# [('tidak', 'O'), ('banyak', 'O'), ('yang', 'O'), ('tahu', 'O'), ('kalau', 'O'), ('penggunaan', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('itu', 'O'), ('sangat', 'O'), ('menguntungkan', 'O')]
# [('tidak', 'B'), ('banyak', 'O'), ('yang', 'O'), ('tahu', 'O'), ('kalau', 'O'), ('penggunaan', 'B'), ('e-channel', 'B'), ('bca', 'I'), ('itu', 'O'), ('sangat', 'O'), ('menguntungkan', 'B')]
# 45
# [('ibu', 'O'), ('saya', 'O'), ('sudah', 'O'), ('saya', 'O'), ('ajak', 'O'), ('untuk', 'O'), ('menggunakan', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('karena', 'O'), ('memang', 'O'), ('segala', 'O'), ('transaksi', 'O'), ('dalam', 'O'), ('kelhidupan', 'O'), ('menjadi', 'O'), ('lebih', 'O'), ('praktis', 'O')]
# [('ibu', 'O'), ('saya', 'O'), ('sudah', 'O'), ('saya', 'O'), ('ajak', 'B'), ('untuk', 'O'), ('menggunakan', 'B'), ('e-channel', 'B'), ('bca', 'I'), ('karena', 'O'), ('memang', 'O'), ('segala', 'O'), ('transaksi', 'B'), ('dalam', 'O'), ('kelhidupan', 'O'), ('menjadi', 'O'), ('lebih', 'O'), ('praktis', 'B')]
# 46
# [('tidak', 'O'), ('perlu', 'O'), ('khawatir', 'O'), ('kalau', 'O'), ('tidak', 'O'), ('punya', 'O'), ('uang', 'O'), ('tunai', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('dapat', 'O'), ('digunakan', 'O'), ('untuk', 'O'), ('bertransaksi', 'O'), ('daring', 'O')]
# [('tidak', 'B'), ('perlu', 'O'), ('khawatir', 'O'), ('kalau', 'O'), ('tidak', 'O'), ('punya', 'O'), ('uang', 'B'), ('tunai', 'I'), ('e-channel', 'B'), ('bca', 'I'), ('dapat', 'O'), ('digunakan', 'I'), ('untuk', 'O'), ('bertransaksi', 'B'), ('daring', 'O')]
# 47
# [('kok', 'O'), ('saya', 'O'), ('coba', 'O'), ('pakai', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('ya', 'O'), ('padahal', 'O'), ('teman', 'O'), ('saya', 'O'), ('aman-aman', 'O'), ('saja', 'O')]
# [('kok', 'O'), ('saya', 'O'), ('coba', 'O'), ('pakai', 'O'), ('e-channel', 'B'), ('bca', 'I'), ('tidak', 'O'), ('bisa', 'O'), ('ya', 'O'), ('padahal', 'O'), ('teman', 'O'), ('saya', 'O'), ('aman-aman', 'B'), ('saja', 'O')]
# 48
# [('@bankBCA', 'O'), ('kakakku', 'O'), ('sudah', 'O'), ('tidak', 'O'), ('mau', 'O'), ('menggunakan', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('karena', 'O'), ('ribet', 'O'), ('memakainya', 'O'), ('katanya', 'O')]
# [('@bankBCA', 'B'), ('kakakku', 'O'), ('sudah', 'O'), ('tidak', 'B'), ('mau', 'O'), ('menggunakan', 'B'), ('e-channel', 'B'), ('bca', 'I'), ('karena', 'O'), ('ribet', 'B'), ('memakainya', 'B'), ('katanya', 'O')]
# 49
# [('saya', 'O'), ('ingin', 'O'), ('menggunakan', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('bagaimana', 'O'), ('ya', 'O'), ('caranya', 'O')]
# [('saya', 'O'), ('ingin', 'O'), ('menggunakan', 'B'), ('e-channel', 'B'), ('bca', 'I'), ('bagaimana', 'O'), ('ya', 'O'), ('caranya', 'B')]
# 50
# [('kalau', 'O'), ('saya', 'O'), ('menerima', 'O'), ('transferan', 'O'), ('kesulitannya', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('tahu', 'O'), ('dari', 'O'), ('siapa', 'O'), ('pengirimannya', 'O'), ('sama', 'O'), ('dengan', 'O'), ('dikenakan', 'O'), ('biaya', 'O'), ('administrasi', 'O'), ('bila', 'O'), ('saya', 'O'), ('berkirim', 'O'), ('surat', 'O'), ('beda', 'O'), ('bank', 'O'), ('seperti', 'O'), ('transfer', 'O'), ('dikenakan', 'O'), ('biaya', 'O'), ('dan', 'O'), ('dikenakan', 'O'), ('biaya', 'O'), ('juga', 'O'), ('walaupun', 'O'), ('sesama', 'O'), ('bca', 'O'), ('jadi', 'O'), ('kalau', 'O'), ('bisa', 'O'), ('digratiskan', 'O'), ('saja', 'O')]
# [('kalau', 'O'), ('saya', 'O'), ('menerima', 'B'), ('transferan', 'B'), ('kesulitannya', 'B'), ('tidak', 'B'), ('bisa', 'O'), ('tahu', 'O'), ('dari', 'O'), ('siapa', 'O'), ('pengirimannya', 'B'), ('sama', 'O'), ('dengan', 'O'), ('dikenakan', 'B'), ('biaya', 'B'), ('administrasi', 'O'), ('bila', 'O'), ('saya', 'O'), ('berkirim', 'O'), ('surat', 'B'), ('beda', 'B'), ('bank', 'O'), ('seperti', 'O'), ('transfer', 'B'), ('dikenakan', 'B'), ('biaya', 'B'), ('dan', 'O'), ('dikenakan', 'B'), ('biaya', 'O'), ('juga', 'O'), ('walaupun', 'O'), ('sesama', 'O'), ('bca', 'B'), ('jadi', 'O'), ('kalau', 'O'), ('bisa', 'O'), ('digratiskan', 'B'), ('saja', 'O')]
# 51
# [('berjualan', 'O'), ('dengan', 'O'), ('mengandalkan', 'O'), ('internet', 'O'), ('banking', 'O'), ('mobile', 'O'), ('banking', 'O'), ('dan', 'O'), ('e-channel', 'O'), ('bca', 'O'), ('sangat', 'O'), ('membantu', 'O')]
# [('berjualan', 'O'), ('dengan', 'O'), ('mengandalkan', 'B'), ('internet', 'B'), ('banking', 'I'), ('mobile', 'B'), ('banking', 'I'), ('dan', 'O'), ('e-channel', 'B'), ('bca', 'B'), ('sangat', 'O'), ('membantu', 'B')]
# 52
# [('Buka', 'O'), ('produk', 'O'), ('reksadana', 'O'), ('deposito', 'O'), ('pembelian', 'O'), ('surat', 'O'), ('berharga', 'O'), ('secara', 'O'), ('mobile', 'O'), ('melalui', 'O'), ('e-channel', 'O'), ('BCA', 'O'), ('sangat', 'O'), ('gampang', 'O'), ('prosedurnya', 'O')]
# [('Buka', 'O'), ('produk', 'B'), ('reksadana', 'I'), ('deposito', 'B'), ('pembelian', 'B'), ('surat', 'O'), ('berharga', 'O'), ('secara', 'O'), ('mobile', 'I'), ('melalui', 'O'), ('e-channel', 'B'), ('BCA', 'I'), ('sangat', 'O'), ('gampang', 'B'), ('prosedurnya', 'B')]
# 53
# [('saya', 'O'), ('merasa', 'O'), ('kesulitan', 'O'), ('dengan', 'O'), ('token', 'O'), ('bca', 'O'), ('ini', 'O'), ('transaksi', 'O'), ('menjadi', 'O'), ('lebih', 'O'), ('ribet', 'O'), ('kalau', 'O'), ('hilang', 'O'), ('juga', 'O'), ('pusing', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('transaksi', 'O')]
# [('saya', 'O'), ('merasa', 'O'), ('kesulitan', 'B'), ('dengan', 'O'), ('token', 'B'), ('bca', 'I'), ('ini', 'O'), ('transaksi', 'B'), ('menjadi', 'B'), ('lebih', 'O'), ('ribet', 'B'), ('kalau', 'O'), ('hilang', 'B'), ('juga', 'O'), ('pusing', 'B'), ('enggak', 'B'), ('bisa', 'O'), ('transaksi', 'O')]
# 54
# [('@halobca', 'O'), ('admin', 'O'), ('masa', 'O'), ('setiap', 'O'), ('mengajukan', 'O'), ('respons', 'O'), ('keybca', 'O'), ('salah', 'O'), ('nomor', 'O'), ('melulu', 'O'), ('padahal', 'O'), ('sudah', 'O'), ('benar', 'O'), ('diketik', 'O'), ('keybca-nya', 'O'), ('deh', 'O'), ('aneh', 'O')]
# [('@halobca', 'B'), ('admin', 'O'), ('masa', 'O'), ('setiap', 'O'), ('mengajukan', 'B'), ('respons', 'B'), ('keybca', 'B'), ('salah', 'O'), ('nomor', 'O'), ('melulu', 'O'), ('padahal', 'O'), ('sudah', 'O'), ('benar', 'O'), ('diketik', 'B'), ('keybca-nya', 'B'), ('deh', 'O'), ('aneh', 'O')]
# 55
# [('tombol', 'O'), ('token', 'O'), ('bca', 'O'), ('ini', 'O'), ('kok', 'O'), ('jebol', 'O'), ('ya', 'O'), ('saya', 'O'), ('baru', 'O'), ('pakai', 'O'), ('sekali', 'O'), ('padahal', 'O')]
# [('tombol', 'B'), ('token', 'B'), ('bca', 'I'), ('ini', 'O'), ('kok', 'O'), ('jebol', 'B'), ('ya', 'O'), ('saya', 'O'), ('baru', 'O'), ('pakai', 'O'), ('sekali', 'O'), ('padahal', 'O')]
# 56
# [('saya', 'O'), ('heran', 'O'), ('token', 'O'), ('bca', 'O'), ('saya', 'O'), ('selalu', 'O'), ('rusak', 'O'), ('setiap', 'O'), ('diganti', 'O'), ('juga', 'O'), ('terkena', 'O'), ('biaya', 'O'), ('sial', 'O')]
# [('saya', 'O'), ('heran', 'O'), ('token', 'B'), ('bca', 'I'), ('saya', 'O'), ('selalu', 'O'), ('rusak', 'B'), ('setiap', 'O'), ('diganti', 'B'), ('juga', 'O'), ('terkena', 'O'), ('biaya', 'B'), ('sial', 'O')]
# 57
# [('token', 'O'), ('internet', 'O'), ('banking', 'O'), ('saya', 'O'), ('terblokir', 'O'), ('karena', 'O'), ('dimainkan', 'O'), ('oleh', 'O'), ('anak', 'O'), ('saya', 'O'), ('lalu', 'O'), ('saya', 'O'), ('mengurus', 'O'), ('ke', 'O'), ('bca', 'O'), ('kcp', 'O'), ('pasar', 'O'), ('wetan', 'O'), ('di', 'O'), ('bagian', 'O'), ('cso-nya', 'O'), ('tetapi', 'O'), ('saya', 'O'), ('harus', 'O'), ('menunggu', 'O'), ('sampai', 'O'), ('3-4', 'O'), ('hari', 'O'), ('karena', 'O'), ('menunggu', 'O'), ('kabar', 'O'), ('dari', 'O'), ('bca', 'O'), ('pusat', 'O'), ('sedangkan', 'O'), ('saya', 'O'), ('sangat', 'O'), ('membutuhkan', 'O'), ('sekali', 'O'), ('internet', 'O'), ('banking', 'O')]
# [('token', 'B'), ('internet', 'B'), ('banking', 'I'), ('saya', 'O'), ('terblokir', 'B'), ('karena', 'O'), ('dimainkan', 'B'), ('oleh', 'O'), ('anak', 'O'), ('saya', 'O'), ('lalu', 'O'), ('saya', 'O'), ('mengurus', 'B'), ('ke', 'O'), ('bca', 'B'), ('kcp', 'B'), ('pasar', 'O'), ('wetan', 'O'), ('di', 'O'), ('bagian', 'O'), ('cso-nya', 'B'), ('tetapi', 'O'), ('saya', 'O'), ('harus', 'O'), ('menunggu', 'O'), ('sampai', 'O'), ('3-4', 'O'), ('hari', 'O'), ('karena', 'O'), ('menunggu', 'O'), ('kabar', 'O'), ('dari', 'O'), ('bca', 'B'), ('pusat', 'B'), ('sedangkan', 'O'), ('saya', 'O'), ('sangat', 'O'), ('membutuhkan', 'B'), ('sekali', 'O'), ('internet', 'B'), ('banking', 'I')]
# 58
# [('pakai', 'O'), ('internet', 'O'), ('banking', 'O'), ('bca', 'O'), ('selalu', 'O'), ('gagal', 'O'), ('memasukkan', 'O'), ('angka', 'O'), ('keybca-nya', 'O'), ('jadi', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('melakukan', 'O'), ('transfer', 'O')]
# [('pakai', 'O'), ('internet', 'B'), ('banking', 'I'), ('bca', 'I'), ('selalu', 'O'), ('gagal', 'B'), ('memasukkan', 'B'), ('angka', 'B'), ('keybca-nya', 'B'), ('jadi', 'O'), ('tidak', 'B'), ('bisa', 'O'), ('melakukan', 'O'), ('transfer', 'B')]
# 59
# [('saat', 'O'), ('saya', 'O'), ('menggunakan', 'O'), ('internet', 'O'), ('banking', 'O'), ('tokennya', 'O'), ('tidak', 'O'), ('terkoneksi', 'O'), ('dan', 'O'), ('saya', 'O'), ('tetap', 'O'), ('harus', 'O'), ('membayar', 'O'), ('biaya', 'O'), ('tokennya', 'O'), ('seharusnya', 'O'), ('pihak', 'O'), ('bca', 'O'), ('tidak', 'O'), ('ada', 'O'), ('kebijakan', 'O'), ('tidak', 'O'), ('bayar', 'O'), ('token', 'O'), ('di', 'O'), ('saat', 'O'), ('bukan', 'O'), ('kesalahan', 'O'), ('saya', 'O'), ('saya', 'O'), ('sudah', 'O'), ('melaporkan', 'O'), ('ke', 'O'), ('1500888', 'O'), ('namun', 'O'), ('tidak', 'O'), ('hari', 'O'), ('itu', 'O'), ('bisa', 'O'), ('diselesaikan', 'O'), ('akhirnya', 'O'), ('saya', 'O'), ('harus', 'O'), ('ke', 'O'), ('atm', 'O'), ('dan', 'O'), ('membuat', 'O'), ('ribet', 'O')]
# [('saat', 'O'), ('saya', 'O'), ('menggunakan', 'B'), ('internet', 'B'), ('banking', 'I'), ('tokennya', 'B'), ('tidak', 'B'), ('terkoneksi', 'I'), ('dan', 'O'), ('saya', 'O'), ('tetap', 'O'), ('harus', 'O'), ('membayar', 'O'), ('biaya', 'B'), ('tokennya', 'O'), ('seharusnya', 'O'), ('pihak', 'O'), ('bca', 'I'), ('tidak', 'O'), ('ada', 'O'), ('kebijakan', 'O'), ('tidak', 'O'), ('bayar', 'I'), ('token', 'O'), ('di', 'O'), ('saat', 'O'), ('bukan', 'B'), ('kesalahan', 'I'), ('saya', 'O'), ('saya', 'O'), ('sudah', 'O'), ('melaporkan', 'O'), ('ke', 'O'), ('1500888', 'O'), ('namun', 'O'), ('tidak', 'O'), ('hari', 'O'), ('itu', 'O'), ('bisa', 'O'), ('diselesaikan', 'B'), ('akhirnya', 'O'), ('saya', 'O'), ('harus', 'O'), ('ke', 'O'), ('atm', 'B'), ('dan', 'O'), ('membuat', 'B'), ('ribet', 'B')]
# 60
# [('saya', 'O'), ('coba', 'O'), ('beberapa', 'O'), ('kali', 'O'), ('menggunakan', 'O'), ('token', 'O'), ('bca', 'O'), ('tetapi', 'O'), ('kenapa', 'O'), ('bisa', 'O'), ('terblokir', 'O'), ('ya', 'O')]
# [('saya', 'O'), ('coba', 'O'), ('beberapa', 'O'), ('kali', 'O'), ('menggunakan', 'B'), ('token', 'B'), ('bca', 'I'), ('tetapi', 'O'), ('kenapa', 'O'), ('bisa', 'O'), ('terblokir', 'B'), ('ya', 'O')]
# 61
# [('masa', 'O'), ('sedang', 'O'), ('dipakai', 'O'), ('token', 'O'), ('bca-nya', 'O'), ('bisa', 'O'), ('mati', 'O'), ('sendiri', 'O'), ('aneh', 'O'), ('enggak', 'O'), ('sih', 'O')]
# [('masa', 'O'), ('sedang', 'O'), ('dipakai', 'B'), ('token', 'B'), ('bca-nya', 'I'), ('bisa', 'O'), ('mati', 'B'), ('sendiri', 'O'), ('aneh', 'O'), ('enggak', 'O'), ('sih', 'O')]
# 62
# [('Sudah', 'O'), ('bagus', 'O'), ('tetapi', 'O'), ('agak', 'O'), ('kerepotan', 'O'), ('dengan', 'O'), ('token', 'O'), ('BCA', 'O')]
# [('Sudah', 'O'), ('bagus', 'B'), ('tetapi', 'O'), ('agak', 'O'), ('kerepotan', 'B'), ('dengan', 'O'), ('token', 'B'), ('BCA', 'I')]
# 63
# [('@halobca', 'O'), ('sekarang', 'O'), ('sudah', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('bayar', 'O'), ('cc', 'O'), ('bca', 'O'), ('lewat', 'O'), ('klikbca', 'O'), ('keterangan', 'O'), ('transaksi', 'O'), ('tidak', 'O'), ('valid', 'O'), ('dan', 'O'), ('sudah', 'O'), ('seminggu', 'O'), ('bagaimana', 'O'), ('nih', 'O')]
# [('@halobca', 'B'), ('sekarang', 'O'), ('sudah', 'O'), ('enggak', 'B'), ('bisa', 'O'), ('bayar', 'B'), ('cc', 'I'), ('bca', 'I'), ('lewat', 'O'), ('klikbca', 'B'), ('keterangan', 'B'), ('transaksi', 'B'), ('tidak', 'B'), ('valid', 'I'), ('dan', 'O'), ('sudah', 'O'), ('seminggu', 'B'), ('bagaimana', 'O'), ('nih', 'O')]
# 64
# [('mau', 'O'), ('tanya', 'O'), ('kenapa', 'O'), ('internet', 'O'), ('banking', 'O'), ('bca', 'O'), ('saya', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('masuk', 'O'), ('dan', 'O'), ('juga', 'O'), ('enggak', 'O'), ('ada', 'O'), ('keterangan', 'O'), ('apa-apa', 'O')]
# [('mau', 'O'), ('tanya', 'O'), ('kenapa', 'O'), ('internet', 'B'), ('banking', 'I'), ('bca', 'B'), ('saya', 'O'), ('enggak', 'B'), ('bisa', 'O'), ('masuk', 'I'), ('dan', 'O'), ('juga', 'O'), ('enggak', 'O'), ('ada', 'O'), ('keterangan', 'I'), ('apa-apa', 'O')]
# 65
# [('saya', 'O'), ('sudah', 'O'), ('mendaftar', 'O'), ('klikbca', 'O'), ('di', 'O'), ('cabang', 'O'), ('bca', 'O'), ('saya', 'O'), ('mendaftar', 'O'), ('di', 'O'), ('klikpay-nya', 'O'), ('tetapi', 'O'), ('saat', 'O'), ('akan', 'O'), ('diaktivasi', 'O'), ('di', 'O'), ('klikbca', 'O'), ('tidak', 'O'), ('ada', 'O'), ('aktivasi', 'O'), ('klikpay', 'O'), ('di', 'O'), ('menu', 'O'), ('administrasi', 'O')]
# [('saya', 'O'), ('sudah', 'O'), ('mendaftar', 'B'), ('klikbca', 'B'), ('di', 'O'), ('cabang', 'B'), ('bca', 'I'), ('saya', 'O'), ('mendaftar', 'O'), ('di', 'O'), ('klikpay-nya', 'B'), ('tetapi', 'O'), ('saat', 'O'), ('akan', 'O'), ('diaktivasi', 'B'), ('di', 'O'), ('klikbca', 'B'), ('tidak', 'O'), ('ada', 'O'), ('aktivasi', 'B'), ('klikpay', 'O'), ('di', 'O'), ('menu', 'O'), ('administrasi', 'O')]
# 66
# [('@halobca', 'O'), ('admin', 'O'), ('barusan', 'O'), ('saya', 'O'), ('transfer', 'O'), ('pakai', 'O'), ('klikbca', 'O'), ('tetapi', 'O'), ('saldo', 'O'), ('terpotong', 'O'), ('dan', 'O'), ('di', 'O'), ('histori', 'O'), ('transfer', 'O'), ('tidak', 'O'), ('muncul', 'O'), ('dan', 'O'), ('tidak', 'O'), ('sampai', 'O'), ('ke', 'O'), ('penerima', 'O'), ('tolong', 'O')]
# [('@halobca', 'B'), ('admin', 'O'), ('barusan', 'O'), ('saya', 'O'), ('transfer', 'B'), ('pakai', 'O'), ('klikbca', 'B'), ('tetapi', 'O'), ('saldo', 'B'), ('terpotong', 'I'), ('dan', 'O'), ('di', 'O'), ('histori', 'B'), ('transfer', 'B'), ('tidak', 'O'), ('muncul', 'O'), ('dan', 'O'), ('tidak', 'O'), ('sampai', 'O'), ('ke', 'O'), ('penerima', 'B'), ('tolong', 'O')]
# 67
# [('@halobca', 'O'), ('klikbca', 'O'), ('kenapa', 'O'), ('memuatnya', 'O'), ('lama', 'O'), ('ya', 'O'), ('baik', 'O'), ('di', 'O'), ('desktop', 'O'), ('maupun', 'O'), ('di', 'O'), ('peramban', 'O'), ('seluler', 'O'), ('nih', 'O'), ('payah', 'O'), ('yeu', 'O')]
# [('@halobca', 'B'), ('klikbca', 'B'), ('kenapa', 'O'), ('memuatnya', 'B'), ('lama', 'B'), ('ya', 'O'), ('baik', 'O'), ('di', 'O'), ('desktop', 'B'), ('maupun', 'O'), ('di', 'O'), ('peramban', 'O'), ('seluler', 'O'), ('nih', 'O'), ('payah', 'B'), ('yeu', 'O')]
# 68
# [('@halobca', 'O'), ('web', 'O'), ('klikbca', 'O'), ('lagi', 'O'), ('error', 'O'), ('mau', 'O'), ('masuk', 'O'), ('susah', 'O'), ('banget', 'O'), ('jadinya', 'O'), ('lambat', 'O'), ('padahal', 'O'), ('internet', 'O'), ('lancar', 'O'), ('&', 'O'), ('peramban', 'O'), ('yang', 'O'), ('lain', 'O'), ('bisa', 'O'), ('bagaimana', 'O'), ('ini', 'O'), ('bca', 'O'), ('benarkan', 'O'), ('dong', 'O')]
# [('@halobca', 'B'), ('web', 'B'), ('klikbca', 'B'), ('lagi', 'O'), ('error', 'B'), ('mau', 'O'), ('masuk', 'B'), ('susah', 'B'), ('banget', 'O'), ('jadinya', 'O'), ('lambat', 'B'), ('padahal', 'O'), ('internet', 'B'), ('lancar', 'B'), ('&', 'O'), ('peramban', 'O'), ('yang', 'O'), ('lain', 'O'), ('bisa', 'O'), ('bagaimana', 'O'), ('ini', 'O'), ('bca', 'B'), ('benarkan', 'B'), ('dong', 'O')]
# 69
# [('@halobca', 'O'), ('siang', 'O'), ('mau', 'O'), ('nanya', 'O'), ('kok', 'O'), ('kalau', 'O'), ('via', 'O'), ('desktop', 'O'), ('di', 'O'), ('laptop', 'O'), ('kadang', 'O'), ('website', 'O'), ('klikbca', 'O'), ('buat', 'O'), ('internet', 'O'), ('banking', 'O'), ('lama', 'O'), ('dibuka', 'O'), ('ya', 'O'), ('kalau', 'O'), ('via', 'O'), ('telepon', 'O'), ('genggam', 'O'), ('bisa', 'O'), ('saja', 'O'), ('dibuka', 'O'), ('masalah', 'O'), ('lagi', 'O'), ('ni', 'O')]
# [('@halobca', 'B'), ('siang', 'O'), ('mau', 'O'), ('nanya', 'O'), ('kok', 'O'), ('kalau', 'O'), ('via', 'O'), ('desktop', 'B'), ('di', 'O'), ('laptop', 'B'), ('kadang', 'O'), ('website', 'B'), ('klikbca', 'B'), ('buat', 'O'), ('internet', 'B'), ('banking', 'I'), ('lama', 'O'), ('dibuka', 'B'), ('ya', 'O'), ('kalau', 'O'), ('via', 'O'), ('telepon', 'B'), ('genggam', 'I'), ('bisa', 'O'), ('saja', 'O'), ('dibuka', 'O'), ('masalah', 'B'), ('lagi', 'O'), ('ni', 'O')]
# 70
# [('@kartukreditbca', 'O'), ('@halobca', 'O'), ('admin', 'O'), ('saya', 'O'), ('kok', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('buka', 'O'), ('tagihan', 'O'), ('e-statement', 'O'), ('kata', 'O'), ('sandi', 'O'), ('enggak', 'O'), ('saya', 'O'), ('ubah', 'O'), ('saya', 'O'), ('mau', 'O'), ('reset', 'O'), ('via', 'O'), ('e-form', 'O'), ('juga', 'O'), ('enggak', 'O'), ('terbuka', 'O'), ('websitenya', 'O')]
# [('@kartukreditbca', 'B'), ('@halobca', 'B'), ('admin', 'O'), ('saya', 'O'), ('kok', 'O'), ('enggak', 'B'), ('bisa', 'O'), ('buka', 'O'), ('tagihan', 'I'), ('e-statement', 'B'), ('kata', 'O'), ('sandi', 'O'), ('enggak', 'B'), ('saya', 'O'), ('ubah', 'O'), ('saya', 'O'), ('mau', 'O'), ('reset', 'B'), ('via', 'O'), ('e-form', 'B'), ('juga', 'O'), ('enggak', 'O'), ('terbuka', 'I'), ('websitenya', 'O')]
# 71
# [('@halobca', 'O'), ('saya', 'O'), ('transfer', 'O'), ('pakai', 'O'), ('klikbca', 'O'), ('ke', 'O'), ('rekening', 'O'), ('mandiri', 'O'), ('kok', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('ya', 'O'), ('malah', 'O'), ('balik', 'O'), ('ke', 'O'), ('menu', 'O'), ('utama', 'O')]
# [('@halobca', 'B'), ('saya', 'O'), ('transfer', 'B'), ('pakai', 'O'), ('klikbca', 'B'), ('ke', 'O'), ('rekening', 'B'), ('mandiri', 'I'), ('kok', 'O'), ('enggak', 'O'), ('bisa', 'O'), ('ya', 'O'), ('malah', 'O'), ('balik', 'O'), ('ke', 'O'), ('menu', 'B'), ('utama', 'O')]
# 72
# [('@halobca', 'O'), ('tadi', 'O'), ('coba', 'O'), ('bayar', 'O'), ('bpjs', 'O'), ('kesehatan', 'O'), ('pakai', 'O'), ('menu', 'O'), ('di', 'O'), ('klikbca', 'O'), ('kok', 'O'), ('error', 'O'), ('terus', 'O'), ('ya', 'O'), ('pesannya', 'O'), ('nomor', 'O'), ('lanjut', 'O')]
# [('@halobca', 'B'), ('tadi', 'O'), ('coba', 'O'), ('bayar', 'B'), ('bpjs', 'I'), ('kesehatan', 'I'), ('pakai', 'O'), ('menu', 'O'), ('di', 'O'), ('klikbca', 'B'), ('kok', 'O'), ('error', 'B'), ('terus', 'O'), ('ya', 'O'), ('pesannya', 'B'), ('nomor', 'B'), ('lanjut', 'O')]
# 73
# [('@halobca', 'O'), ('selamat', 'O'), ('malam', 'O'), ('halobca', 'O'), ('akun', 'O'), ('klikbca', 'O'), ('saya', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('menambahkan', 'O'), ('rekening', 'O'), ('tujuan', 'O'), ('untuk', 'O'), ('transfer', 'O'), ('mohon', 'O'), ('responsnya', 'O'), ('terima', 'O'), ('kasih', 'O')]
# [('@halobca', 'B'), ('selamat', 'O'), ('malam', 'O'), ('halobca', 'O'), ('akun', 'B'), ('klikbca', 'B'), ('saya', 'O'), ('tidak', 'B'), ('bisa', 'I'), ('menambahkan', 'B'), ('rekening', 'B'), ('tujuan', 'I'), ('untuk', 'O'), ('transfer', 'B'), ('mohon', 'O'), ('responsnya', 'B'), ('terima', 'O'), ('kasih', 'O')]
# 74
# [('ketika', 'O'), ('saya', 'O'), ('melakukan', 'O'), ('pengisian', 'O'), ('token', 'O'), ('listrik', 'O'), ('melalui', 'O'), ('internet', 'O'), ('banking', 'O'), ('di', 'O'), ('malam', 'O'), ('hari', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('padahal', 'O'), ('saya', 'O'), ('sudah', 'O'), ('mencoba', 'O'), ('3', 'O'), ('kali', 'O')]
# [('ketika', 'O'), ('saya', 'O'), ('melakukan', 'O'), ('pengisian', 'B'), ('token', 'B'), ('listrik', 'I'), ('melalui', 'O'), ('internet', 'B'), ('banking', 'I'), ('di', 'O'), ('malam', 'O'), ('hari', 'O'), ('tidak', 'B'), ('bisa', 'O'), ('padahal', 'O'), ('saya', 'O'), ('sudah', 'O'), ('mencoba', 'O'), ('3', 'O'), ('kali', 'O')]
# 75
# [('internet', 'O'), ('banking', 'O'), ('saya', 'O'), ('sulit', 'O'), ('terhubung', 'O'), ('susah', 'O'), ('masuk', 'O'), ('mungkin', 'O'), ('error', 'O')]
# [('internet', 'B'), ('banking', 'I'), ('saya', 'O'), ('sulit', 'O'), ('terhubung', 'B'), ('susah', 'B'), ('masuk', 'B'), ('mungkin', 'O'), ('error', 'B')]
# 76
# [('mencetak', 'O'), ('rekening', 'O'), ('melalui', 'O'), ('internet', 'O'), ('banking', 'O'), ('lama', 'O'), ('saya', 'O'), ('menunggu', 'O'), ('selama', 'O'), ('2', 'O'), ('menit', 'O')]
# [('mencetak', 'B'), ('rekening', 'I'), ('melalui', 'O'), ('internet', 'B'), ('banking', 'I'), ('lama', 'B'), ('saya', 'O'), ('menunggu', 'B'), ('selama', 'O'), ('2', 'O'), ('menit', 'O')]
# 77
# [('pada', 'O'), ('saat', 'O'), ('menggunakan', 'O'), ('internet', 'O'), ('banking', 'O'), ('untuk', 'O'), ('transfer', 'O'), ('proses', 'O'), ('memuatnya', 'O'), ('lama', 'O'), ('sekali', 'O')]
# [('pada', 'O'), ('saat', 'O'), ('menggunakan', 'B'), ('internet', 'B'), ('banking', 'I'), ('untuk', 'O'), ('transfer', 'B'), ('proses', 'B'), ('memuatnya', 'B'), ('lama', 'B'), ('sekali', 'O')]
# 78
# [('Tampilan', 'O'), ('klikBCA', 'O'), ('sangat', 'O'), ('modern', 'O')]
# [('Tampilan', 'B'), ('klikBCA', 'B'), ('sangat', 'O'), ('modern', 'B')]
# 79
# [('@halobca', 'O'), ('untuk', 'O'), ('mengisi', 'O'), ('saldo', 'O'), ('t-cash', 'O'), ('bisa', 'O'), ('tidak', 'O'), ('menggunakan', 'O'), ('klikbca', 'O'), ('terima', 'O'), ('kasih', 'O')]
# [('@halobca', 'B'), ('untuk', 'O'), ('mengisi', 'O'), ('saldo', 'B'), ('t-cash', 'B'), ('bisa', 'O'), ('tidak', 'B'), ('menggunakan', 'I'), ('klikbca', 'B'), ('terima', 'O'), ('kasih', 'O')]
# 80
# [('@tokopediacare', 'O'), ('admin', 'O'), ('saya', 'O'), ('memilih', 'O'), ('metode', 'O'), ('pembayaran', 'O'), ('klikbca', 'O'), ('dengan', 'O'), ('kode', 'O'), ('promo', 'O'), ('paling', 'O'), ('untung', 'O'), ('bisa', 'O'), ('kan', 'O'), ('ya', 'O')]
# [('@tokopediacare', 'B'), ('admin', 'O'), ('saya', 'O'), ('memilih', 'O'), ('metode', 'B'), ('pembayaran', 'B'), ('klikbca', 'B'), ('dengan', 'O'), ('kode', 'B'), ('promo', 'B'), ('paling', 'O'), ('untung', 'O'), ('bisa', 'O'), ('kan', 'O'), ('ya', 'O')]
# 81
# [('@halobca', 'O'), ('malam', 'O'), ('mau', 'O'), ('tanya', 'O'), ('seperti', 'O'), ('pbb', 'O'), ('objek', 'O'), ('tanah', 'O'), ('di', 'O'), ('yogyakarta', 'O'), ('mau', 'O'), ('bayar', 'O'), ('di', 'O'), ('klikbca', 'O'), ('bisa', 'O')]
# [('@halobca', 'B'), ('malam', 'O'), ('mau', 'O'), ('tanya', 'O'), ('seperti', 'O'), ('pbb', 'O'), ('objek', 'O'), ('tanah', 'O'), ('di', 'O'), ('yogyakarta', 'O'), ('mau', 'O'), ('bayar', 'B'), ('di', 'O'), ('klikbca', 'B'), ('bisa', 'O')]
# 82
# [('mohon', 'O'), ('klikbca', 'O'), ('saya', 'O'), ('terblokir', 'O'), ('saya', 'O'), ('sedang', 'O'), ('ada', 'O'), ('di', 'O'), ('makati', 'O'), ('manila', 'O'), ('sekarang', 'O'), ('saya', 'O'), ('sudah', 'O'), ('mencoba', 'O'), ('menghubungi', 'O'), ('call', 'O'), ('center', 'O'), ('tetapi', 'O'), ('tidak', 'O'), ('bisa', 'O'), ('respons', 'O'), ('dong', 'O'), ('customer', 'O'), ('yang', 'O'), ('sedang', 'O'), ('kesusahan', 'O'), ('ini', 'O')]
# [('mohon', 'O'), ('klikbca', 'B'), ('saya', 'O'), ('terblokir', 'B'), ('saya', 'O'), ('sedang', 'O'), ('ada', 'O'), ('di', 'O'), ('makati', 'O'), ('manila', 'I'), ('sekarang', 'O'), ('saya', 'O'), ('sudah', 'O'), ('mencoba', 'O'), ('menghubungi', 'B'), ('call', 'B'), ('center', 'I'), ('tetapi', 'O'), ('tidak', 'B'), ('bisa', 'O'), ('respons', 'I'), ('dong', 'O'), ('customer', 'B'), ('yang', 'O'), ('sedang', 'O'), ('kesusahan', 'O'), ('ini', 'O')]
# 83
# [('@shopeecare', 'O'), ('bayar', 'O'), ('via', 'O'), ('klikbca', 'O'), ('bisa', 'O'), ('kah', 'O'), ('terima', 'O'), ('kasih', 'O')]
# [('@shopeecare', 'B'), ('bayar', 'B'), ('via', 'O'), ('klikbca', 'B'), ('bisa', 'O'), ('kah', 'O'), ('terima', 'O'), ('kasih', 'O')]
# 84
# [('@halobca', 'O'), ('bayar', 'O'), ('paspor', 'O'), ('lewat', 'O'), ('klikbca', 'O'), ('sudah', 'O'), ('bisa', 'O'), ('belum', 'O'), ('ya', 'O'), ('admin', 'O')]
# [('@halobca', 'B'), ('bayar', 'B'), ('paspor', 'O'), ('lewat', 'O'), ('klikbca', 'B'), ('sudah', 'O'), ('bisa', 'O'), ('belum', 'B'), ('ya', 'O'), ('admin', 'O')]
# 85
# [('@halobca', 'O'), ('untuk', 'O'), ('pembayaran', 'O'), ('tiket', 'O'), ('kereta', 'O'), ('api', 'O'), ('via', 'O'), ('internet', 'O'), ('banking', 'O'), ('atau', 'O'), ('bca', 'O'), ('klikpay', 'O'), ('bagaimana', 'O')]
# [('@halobca', 'B'), ('untuk', 'O'), ('pembayaran', 'B'), ('tiket', 'B'), ('kereta', 'I'), ('api', 'I'), ('via', 'O'), ('internet', 'B'), ('banking', 'I'), ('atau', 'O'), ('bca', 'B'), ('klikpay', 'B'), ('bagaimana', 'O')]
# 86
# [('@bpjskesehatanri', 'O'), ('cara', 'O'), ('bayar', 'O'), ('bpjs', 'O'), ('dengan', 'O'), ('internet', 'O'), ('banking', 'O'), ('bca', 'O'), ('bagaimana', 'O'), ('ya', 'O')]
# [('@bpjskesehatanri', 'B'), ('cara', 'B'), ('bayar', 'B'), ('bpjs', 'I'), ('dengan', 'O'), ('internet', 'B'), ('banking', 'I'), ('bca', 'B'), ('bagaimana', 'O'), ('ya', 'O')]
# 87
# [('menurut', 'O'), ('saya', 'O'), ('di', 'O'), ('antara', 'O'), ('semua', 'O'), ('internet', 'O'), ('banking', 'O'), ('punya', 'O'), ('bca', 'O'), ('paling', 'O'), ('enak', 'O'), ('digunakan', 'O'), ('keren', 'O'), ('dan', 'O'), ('stabil', 'O')]
# [('menurut', 'O'), ('saya', 'O'), ('di', 'O'), ('antara', 'O'), ('semua', 'O'), ('internet', 'B'), ('banking', 'I'), ('punya', 'O'), ('bca', 'B'), ('paling', 'O'), ('enak', 'B'), ('digunakan', 'I'), ('keren', 'B'), ('dan', 'O'), ('stabil', 'B')]
# 88
# ...
# 213
# [('untuk', 'O'), ('menghubungi', 'O'), ('call', 'O'), ('center', 'O'), ('bca', 'O'), ('sangat', 'O'), ('susah', 'O'), ('terhubung', 'O')]
# [('untuk', 'O'), ('menghubungi', 'B'), ('call', 'B'), ('center', 'I'), ('bca', 'I'), ('sangat', 'O'), ('susah', 'B'), ('terhubung', 'O')]
# 214
# [('saya', 'O'), ('mengalami', 'O'), ('kesulitan', 'O'), ('saat', 'O'), ('akan', 'O'), ('menghubungi', 'O'), ('kantor', 'O'), ('bca', 'O'), ('bitung', 'O'), ('saya', 'O'), ('sudah', 'O'), ('melaporkan', 'O'), ('dan', 'O'), ('diinformasikan', 'O'), ('karena', 'O'), ('jaringan', 'O'), ('telkomnya', 'O'), ('saja', 'O'), ('tetapi', 'O'), ('belum', 'O'), ('ada', 'O'), ('tanggapan', 'O'), ('dari', 'O'), ('pihak', 'O'), ('kantor', 'O'), ('cabang', 'O'), ('payah', 'O'), ('banget', 'O'), ('bca', 'O')]
# [('saya', 'O'), ('mengalami', 'B'), ('kesulitan', 'B'), ('saat', 'O'), ('akan', 'O'), ('menghubungi', 'B'), ('kantor', 'B'), ('bca', 'I'), ('bitung', 'B'), ('saya', 'O'), ('sudah', 'O'), ('melaporkan', 'O'), ('dan', 'O'), ('diinformasikan', 'B'), ('karena', 'O'), ('jaringan', 'B'), ('telkomnya', 'B'), ('saja', 'O'), ('tetapi', 'O'), ('belum', 'O'), ('ada', 'O'), ('tanggapan', 'O'), ('dari', 'O'), ('pihak', 'O'), ('kantor', 'O'), ('cabang', 'I'), ('payah', 'B'), ('banget', 'O'), ('bca', 'B')]
# 215
# [('daripada', 'O'), ('repot-repot', 'O'), ('ke', 'O'), ('KC', 'O'), ('BCA', 'O'), ('terdekat', 'O'), ('mending', 'O'), ('telepon', 'O'), ('call', 'O'), ('center', 'O'), ('semua', 'O'), ('masalah', 'O'), ('bisa', 'O'), ('teratasi', 'O')]
# [('daripada', 'O'), ('repot-repot', 'B'), ('ke', 'O'), ('KC', 'B'), ('BCA', 'I'), ('terdekat', 'O'), ('mending', 'O'), ('telepon', 'B'), ('call', 'B'), ('center', 'I'), ('semua', 'O'), ('masalah', 'B'), ('bisa', 'O'), ('teratasi', 'O')]
# 216
# [('untuk', 'O'), ('menghubungi', 'O'), ('cs', 'O'), ('pada', 'O'), ('waktu', 'O'), ('pagi', 'O'), ('hari', 'O'), ('dan', 'O'), ('siang', 'O'), ('hari', 'O'), ('sulit', 'O'), ('sekali', 'O'), ('tersambung', 'O'), ('bahkan', 'O'), ('saya', 'O'), ('harus', 'O'), ('mengulang', 'O'), ('hingga', 'O'), ('3', 'O'), ('kali', 'O'), ('baru', 'O'), ('tersambung', 'O')]
# [('untuk', 'O'), ('menghubungi', 'B'), ('cs', 'B'), ('pada', 'O'), ('waktu', 'O'), ('pagi', 'O'), ('hari', 'O'), ('dan', 'O'), ('siang', 'O'), ('hari', 'O'), ('sulit', 'O'), ('sekali', 'O'), ('tersambung', 'B'), ('bahkan', 'O'), ('saya', 'O'), ('harus', 'O'), ('mengulang', 'O'), ('hingga', 'O'), ('3', 'O'), ('kali', 'O'), ('baru', 'O'), ('tersambung', 'O')]
# 217
# [('kemarin', 'O'), ('saya', 'O'), ('ada', 'O'), ('masalah', 'O'), ('terus', 'O'), ('komplain', 'O'), ('ke', 'O'), ('call', 'O'), ('center-nya', 'O'), ('BCA', 'O'), ('mereka', 'O'), ('ramah', 'O'), ('dan', 'O'), ('cepat', 'O'), ('tanggap', 'O')]
# [('kemarin', 'O'), ('saya', 'O'), ('ada', 'O'), ('masalah', 'B'), ('terus', 'O'), ('komplain', 'B'), ('ke', 'O'), ('call', 'B'), ('center-nya', 'I'), ('BCA', 'B'), ('mereka', 'O'), ('ramah', 'B'), ('dan', 'O'), ('cepat', 'B'), ('tanggap', 'I')]
# 218
# [('Mantap', 'O'), ('sih', 'O'), ('Call', 'O'), ('Center', 'O'), ('BCA', 'O'), ('gaya', 'O'), ('bicaranya', 'O'), ('bikin', 'O'), ('nyaman', 'O')]
# [('Mantap', 'O'), ('sih', 'O'), ('Call', 'B'), ('Center', 'I'), ('BCA', 'I'), ('gaya', 'O'), ('bicaranya', 'O'), ('bikin', 'O'), ('nyaman', 'B')]
# 219
# [('gue', 'O'), ('itu', 'O'), ('sudah', 'O'), ('ganti', 'O'), ('nomor', 'O'), ('biar', 'O'), ('enggak', 'O'), ('ditelepon', 'O'), ('telemarketing', 'O'), ('bca', 'O'), ('kesal', 'O'), ('banget', 'O'), ('masih', 'O'), ('saja', 'O'), ('dapat', 'O')]
# [('gue', 'O'), ('itu', 'O'), ('sudah', 'O'), ('ganti', 'B'), ('nomor', 'B'), ('biar', 'O'), ('enggak', 'B'), ('ditelepon', 'B'), ('telemarketing', 'B'), ('bca', 'I'), ('kesal', 'B'), ('banget', 'O'), ('masih', 'O'), ('saja', 'O'), ('dapat', 'O')]
# 220
# [('kalau', 'O'), ('enggak', 'O'), ('karena', 'O'), ('telemarketing', 'O'), ('gue', 'O'), ('mungkin', 'O'), ('enggak', 'O'), ('tahu', 'O'), ('kk', 'O'), ('bca', 'O'), ('hehe', 'O')]
# [('kalau', 'O'), ('enggak', 'B'), ('karena', 'O'), ('telemarketing', 'B'), ('gue', 'O'), ('mungkin', 'O'), ('enggak', 'O'), ('tahu', 'O'), ('kk', 'B'), ('bca', 'I'), ('hehe', 'O')]
# 221
# [('gila', 'O'), ('ya', 'O'), ('telemarketing', 'O'), ('bca', 'O'), ('mantap', 'O'), ('banget', 'O'), ('memang', 'O')]
# [('gila', 'O'), ('ya', 'O'), ('telemarketing', 'B'), ('bca', 'I'), ('mantap', 'B'), ('banget', 'O'), ('memang', 'O')]
# 222
# [('saya', 'O'), ('salut', 'O'), ('dengan', 'O'), ('telemarketing', 'O'), ('bca', 'O'), ('yang', 'O'), ('bisa', 'O'), ('membuat', 'O'), ('saya', 'O'), ('mau', 'O'), ('mengajukan', 'O'), ('kk', 'O'), ('@BankBCA', 'O')]
# [('saya', 'O'), ('salut', 'B'), ('dengan', 'O'), ('telemarketing', 'B'), ('bca', 'I'), ('yang', 'O'), ('bisa', 'O'), ('membuat', 'O'), ('saya', 'O'), ('mau', 'O'), ('mengajukan', 'B'), ('kk', 'B'), ('@BankBCA', 'B')]
# 223
# [('saya', 'O'), ('kagum', 'O'), ('sama', 'O'), ('telemarketing', 'O'), ('yang', 'O'), ('menjelaskan', 'O'), ('dengan', 'O'), ('sabar', 'O'), ('tadi', 'O')]
# [('saya', 'O'), ('kagum', 'B'), ('sama', 'O'), ('telemarketing', 'B'), ('yang', 'O'), ('menjelaskan', 'B'), ('dengan', 'O'), ('sabar', 'O'), ('tadi', 'O')]
# 224
# [('malas', 'O'), ('kalau', 'O'), ('ada', 'O'), ('nomor', 'O'), ('yang', 'O'), ('menelepon', 'O'), ('sudah', 'O'), ('pasti', 'O'), ('saja', 'O'), ('itu', 'O'), ('telemarketing', 'O'), ('bca', 'O')]
# [('malas', 'B'), ('kalau', 'O'), ('ada', 'O'), ('nomor', 'B'), ('yang', 'O'), ('menelepon', 'B'), ('sudah', 'O'), ('pasti', 'O'), ('saja', 'O'), ('itu', 'O'), ('telemarketing', 'B'), ('bca', 'I')]
# 225
# [('gigih', 'O'), ('banget', 'O'), ('orang', 'O'), ('bca', 'O'), ('yang', 'O'), ('menawar-nawarkan', 'O'), ('KK', 'O')]
# [('gigih', 'B'), ('banget', 'O'), ('orang', 'O'), ('bca', 'B'), ('yang', 'O'), ('menawar-nawarkan', 'B'), ('KK', 'B')]
# 226
# [('@halobca', 'O'), ('baru', 'O'), ('saja', 'O'), ('saya', 'O'), ('dapat', 'O'), ('telepon', 'O'), ('dari', 'O'), ('bca', 'O'), ('menawarkan', 'O'), ('kartu', 'O'), ('kredit', 'O'), ('padahal', 'O'), ('saya', 'O'), ('enggak', 'O'), ('mengajukan', 'O'), ('apa', 'O'), ('ini', 'O'), ('resmi', 'O')]
# [('@halobca', 'B'), ('baru', 'O'), ('saja', 'O'), ('saya', 'O'), ('dapat', 'O'), ('telepon', 'B'), ('dari', 'O'), ('bca', 'B'), ('menawarkan', 'B'), ('kartu', 'B'), ('kredit', 'I'), ('padahal', 'O'), ('saya', 'O'), ('enggak', 'B'), ('mengajukan', 'B'), ('apa', 'O'), ('ini', 'O'), ('resmi', 'B')]
# 227
# [('@halobca', 'O'), ('sore', 'O'), ('kak', 'O'), ('mau', 'O'), ('bertanya', 'O'), ('barusan', 'O'), ('ditelepon', 'O'), ('nomor', 'O'), ('+622127887388', 'O'), ('katanya', 'O'), ('dari', 'O'), ('bca', 'O'), ('ada', 'O'), ('buat', 'O'), ('kartu', 'O'), ('kredit', 'O'), ('platinum', 'O'), ('benar', 'O'), ('ya', 'O')]
# [('@halobca', 'B'), ('sore', 'O'), ('kak', 'O'), ('mau', 'O'), ('bertanya', 'O'), ('barusan', 'O'), ('ditelepon', 'B'), ('nomor', 'B'), ('+622127887388', 'O'), ('katanya', 'O'), ('dari', 'O'), ('bca', 'B'), ('ada', 'O'), ('buat', 'O'), ('kartu', 'B'), ('kredit', 'I'), ('platinum', 'I'), ('benar', 'O'), ('ya', 'O')]
# 228
# [('bukan', 'O'), ('apa-apa', 'O'), ('kalau', 'O'), ('diterusin', 'O'), ('dia', 'O'), ('bisa', 'O'), ('lama', 'O'), ('banget', 'O'), ('menelepon', 'O'), ('yang', 'O'), ('terima', 'O'), ('telepon', 'O'), ('kan', 'O'), ('ada', 'O'), ('kegiatan', 'O'), ('juga', 'O'), ('pas', 'O'), ('ditanya', 'O'), ('intinya', 'O'), ('apa', 'O'), ('cuma', 'O'), ('mau', 'O'), ('promo', 'O'), ('cc', 'O'), ('bca', 'O')]
# [('bukan', 'O'), ('apa-apa', 'O'), ('kalau', 'O'), ('diterusin', 'B'), ('dia', 'O'), ('bisa', 'O'), ('lama', 'B'), ('banget', 'O'), ('menelepon', 'B'), ('yang', 'O'), ('terima', 'O'), ('telepon', 'B'), ('kan', 'O'), ('ada', 'O'), ('kegiatan', 'O'), ('juga', 'O'), ('pas', 'O'), ('ditanya', 'B'), ('intinya', 'O'), ('apa', 'O'), ('cuma', 'O'), ('mau', 'O'), ('promo', 'B'), ('cc', 'I'), ('bca', 'I')]
# 229
# [('bagaimana', 'O'), ('bisa', 'O'), ('telemarketing', 'O'), ('bca', 'O'), ('menawarkan', 'O'), ('kk', 'O'), ('kepada', 'O'), ('saya', 'O')]
# [('bagaimana', 'O'), ('bisa', 'O'), ('telemarketing', 'B'), ('bca', 'I'), ('menawarkan', 'B'), ('kk', 'B'), ('kepada', 'O'), ('saya', 'O')]
# 230
# [('saya', 'O'), ('kesal', 'O'), ('sekali', 'O'), ('dengan', 'O'), ('telemarketing', 'O'), ('bca', 'O'), ('cerewet', 'O')]
# [('saya', 'O'), ('kesal', 'B'), ('sekali', 'O'), ('dengan', 'O'), ('telemarketing', 'B'), ('bca', 'I'), ('cerewet', 'B')]
# 231
# [('@ahokdjarot', 'O'), ('tahu', 'O'), ('sendiri', 'O'), ('teller', 'O'), ('bca', 'O'), ('antrenya', 'O'), ('panjang', 'O'), ('sekali', 'O'), ('@semargoyang', 'O')]
# [('@ahokdjarot', 'B'), ('tahu', 'O'), ('sendiri', 'O'), ('teller', 'B'), ('bca', 'I'), ('antrenya', 'B'), ('panjang', 'B'), ('sekali', 'O'), ('@semargoyang', 'B')]
# 232
# [('ke', 'O'), ('teller', 'O'), ('bca', 'O'), ('mengantre', 'O'), ('lagi', 'O'), ('jam-jam', 'O'), ('sebegini', 'O'), ('aduh', 'O')]
# [('ke', 'O'), ('teller', 'B'), ('bca', 'I'), ('mengantre', 'B'), ('lagi', 'O'), ('jam-jam', 'O'), ('sebegini', 'O'), ('aduh', 'O')]
# 233
# [('teller', 'O'), ('bca', 'O'), ('pondok', 'O'), ('bambu', 'O'), ('lama', 'O'), ('nih', 'O')]
# [('teller', 'B'), ('bca', 'I'), ('pondok', 'B'), ('bambu', 'O'), ('lama', 'B'), ('nih', 'O')]
# 234
# [('lama-lama', 'O'), ('gue', 'O'), ('pacari', 'O'), ('juga', 'O'), ('ni', 'O'), ('teller', 'O'), ('bca', 'O'), ('habisnya', 'O'), ('senyum', 'O'), ('melulu', 'O'), ('tangkas', 'O'), ('lagi', 'O')]
# [('lama-lama', 'B'), ('gue', 'O'), ('pacari', 'O'), ('juga', 'O'), ('ni', 'O'), ('teller', 'B'), ('bca', 'I'), ('habisnya', 'O'), ('senyum', 'B'), ('melulu', 'O'), ('tangkas', 'O'), ('lagi', 'O')]
# 235
# [('abang', 'O'), ('teller', 'O'), ('bca-nya', 'O'), ('mirip', 'O'), ('banget', 'O'), ('nicolas', 'O'), ('segala', 'O'), ('mengomongnya', 'O'), ('aku', 'O'), ('kamu', 'O'), ('ramah', 'O'), ('mudah', 'O'), ('senyum', 'O'), ('dan', 'O'), ('gerak', 'O'), ('cepat', 'O'), ('mantap', 'O'), ('nih', 'O'), ('bca', 'O'), ('dekat', 'O'), ('rumahku', 'O')]
# [('abang', 'O'), ('teller', 'B'), ('bca-nya', 'I'), ('mirip', 'O'), ('banget', 'O'), ('nicolas', 'B'), ('segala', 'O'), ('mengomongnya', 'B'), ('aku', 'O'), ('kamu', 'O'), ('ramah', 'B'), ('mudah', 'B'), ('senyum', 'B'), ('dan', 'O'), ('gerak', 'B'), ('cepat', 'B'), ('mantap', 'B'), ('nih', 'O'), ('bca', 'O'), ('dekat', 'O'), ('rumahku', 'O')]
# 236
# [('kebanyakan', 'O'), ('basa-basi', 'O'), ('sama', 'O'), ('cengengesan', 'O'), ('teller', 'O'), ('bca', 'O'), ('enggak', 'O'), ('tahu', 'O'), ('antrean', 'O'), ('panjang', 'O'), ('banget', 'O'), ('kali', 'O'), ('kayak', 'O'), ('kereta', 'O')]
# [('kebanyakan', 'O'), ('basa-basi', 'O'), ('sama', 'O'), ('cengengesan', 'B'), ('teller', 'B'), ('bca', 'I'), ('enggak', 'B'), ('tahu', 'O'), ('antrean', 'B'), ('panjang', 'O'), ('banget', 'O'), ('kali', 'O'), ('kayak', 'O'), ('kereta', 'B')]
# 237
# [('keasyikkan', 'O'), ('mengobrol', 'O'), ('sama', 'O'), ('teller', 'O'), ('bca', 'O'), ('perbaungan', 'O'), ('sampai', 'O'), ('lupa', 'O'), ('ktp-ku', 'O'), ('sudah', 'O'), ('dibalikkan', 'O'), ('heheh', 'O')]
# [('keasyikkan', 'B'), ('mengobrol', 'B'), ('sama', 'O'), ('teller', 'B'), ('bca', 'I'), ('perbaungan', 'B'), ('sampai', 'O'), ('lupa', 'O'), ('ktp-ku', 'B'), ('sudah', 'O'), ('dibalikkan', 'B'), ('heheh', 'O')]
# 238
# [('bca', 'O'), ('kutoarjo', 'O'), ('enggak', 'O'), ('antre', 'O'), ('soalnya', 'O'), ('langsung', 'O'), ('ke', 'O'), ('teller', 'O')]
# [('bca', 'B'), ('kutoarjo', 'B'), ('enggak', 'B'), ('antre', 'B'), ('soalnya', 'O'), ('langsung', 'O'), ('ke', 'O'), ('teller', 'B')]
# 239
# [('kata', 'O'), ('teller', 'O'), ('bank', 'O'), ('bca', 'O'), ('tolong', 'O'), ('ya', 'O'), ('mas', 'O'), ('masukan', 'O'), ('ke', 'O'), ('yang', 'O'), ('gambar', 'O'), ('cinta-cinta', 'O'), ('untuk', 'O'), ('saya', 'O'), ('dikira', 'O'), ('apa', 'O'), ('ternyata', 'O'), ('penilaian', 'O'), ('hem', 'O')]
# [('kata', 'O'), ('teller', 'B'), ('bank', 'O'), ('bca', 'I'), ('tolong', 'O'), ('ya', 'O'), ('mas', 'O'), ('masukan', 'O'), ('ke', 'O'), ('yang', 'O'), ('gambar', 'O'), ('cinta-cinta', 'O'), ('untuk', 'O'), ('saya', 'O'), ('dikira', 'B'), ('apa', 'O'), ('ternyata', 'O'), ('penilaian', 'B'), ('hem', 'B')]
# 240
# [('ke', 'O'), ('kantor', 'O'), ('cabang', 'O'), ('bca', 'O'), ('dahulu', 'O'), ('biar', 'O'), ('ketemu', 'O'), ('mas', 'O'), ('rama', 'O'), ('si', 'O'), ('teller', 'O'), ('yang', 'O'), ('murah', 'O'), ('senyum', 'O'), ('itu', 'O')]
# [('ke', 'O'), ('kantor', 'B'), ('cabang', 'I'), ('bca', 'I'), ('dahulu', 'O'), ('biar', 'O'), ('ketemu', 'B'), ('mas', 'O'), ('rama', 'B'), ('si', 'O'), ('teller', 'B'), ('yang', 'O'), ('murah', 'O'), ('senyum', 'B'), ('itu', 'O')]
# 241
# [('mau', 'O'), ('kasih', 'O'), ('tahu', 'O'), ('ada', 'O'), ('teller', 'O'), ('bca', 'O'), ('kcp', 'O'), ('bina', 'O'), ('nusantara', 'O'), ('yang', 'O'), ('namanya', 'O'), ('ayu', 'O'), ('lucu', 'O'), ('banget', 'O'), ('senyumannya', 'O'), ('dan', 'O'), ('pelayanannya', 'O'), ('cepat', 'O')]
# [('mau', 'O'), ('kasih', 'O'), ('tahu', 'O'), ('ada', 'O'), ('teller', 'B'), ('bca', 'I'), ('kcp', 'I'), ('bina', 'O'), ('nusantara', 'B'), ('yang', 'O'), ('namanya', 'O'), ('ayu', 'O'), ('lucu', 'O'), ('banget', 'O'), ('senyumannya', 'B'), ('dan', 'O'), ('pelayanannya', 'B'), ('cepat', 'B')]
# 242
# [('solusi', 'O'), ('pintar', 'O'), ('keren', 'O'), ('juga', 'O'), ('teller', 'O'), ('BCA', 'O'), ('yang', 'O'), ('senyum', 'O'), ('terus', 'O'), ('dan', 'O'), ('sabar', 'O'), ('meskipun', 'O'), ('antrean', 'O'), ('ramai', 'O'), ('terus', 'O'), ('@bca', 'O'), ('kcp', 'O'), ('aneka', 'O'), ('subur', 'O'), ('jatake', 'O'), ('-', 'O'), ('tangerang', 'O')]
# [('solusi', 'O'), ('pintar', 'B'), ('keren', 'B'), ('juga', 'O'), ('teller', 'B'), ('BCA', 'I'), ('yang', 'O'), ('senyum', 'B'), ('terus', 'O'), ('dan', 'O'), ('sabar', 'O'), ('meskipun', 'B'), ('antrean', 'B'), ('ramai', 'B'), ('terus', 'O'), ('@bca', 'B'), ('kcp', 'B'), ('aneka', 'O'), ('subur', 'O'), ('jatake', 'O'), ('-', 'O'), ('tangerang', 'O')]
# 243
# [('teller-nya', 'O'), ('ganteng', 'O'), ('banget', 'O'), ('salah', 'O'), ('fokus', 'O'), ('di', 'O'), ('bank', 'O'), ('bca', 'O'), ('kcp', 'O'), ('cimanggis', 'O')]
# [('teller-nya', 'B'), ('ganteng', 'B'), ('banget', 'O'), ('salah', 'O'), ('fokus', 'B'), ('di', 'O'), ('bank', 'B'), ('bca', 'I'), ('kcp', 'I'), ('cimanggis', 'I')]
# 244
# [('untuk', 'O'), ('antrean', 'O'), ('teller', 'O'), ('di', 'O'), ('bca', 'O'), ('cabang', 'O'), ('tanah', 'O'), ('abang', 'O'), ('antreannya', 'O'), ('lama', 'O'), ('bisa', 'O'), ('sampai', 'O'), ('seperempat', 'O'), ('jam', 'O'), ('khususnya', 'O'), ('saat', 'O'), ('sore', 'O'), ('hari', 'O')]
# [('untuk', 'O'), ('antrean', 'B'), ('teller', 'B'), ('di', 'O'), ('bca', 'B'), ('cabang', 'I'), ('tanah', 'O'), ('abang', 'B'), ('antreannya', 'B'), ('lama', 'B'), ('bisa', 'O'), ('sampai', 'O'), ('seperempat', 'O'), ('jam', 'O'), ('khususnya', 'O'), ('saat', 'O'), ('sore', 'O'), ('hari', 'O')]
# 245
# [('masih', 'O'), ('mengalami', 'O'), ('antrean', 'O'), ('di', 'O'), ('staf', 'O'), ('teller', 'O'), ('cabang', 'O'), ('asia', 'O'), ('mega', 'O'), ('mas', 'O'), ('sampai', 'O'), ('setengah', 'O'), ('jam', 'O'), ('biasanya', 'O'), ('terjadi', 'O'), ('di', 'O'), ('hari', 'O'), ('senin', 'O')]
# [('masih', 'O'), ('mengalami', 'B'), ('antrean', 'B'), ('di', 'O'), ('staf', 'B'), ('teller', 'B'), ('cabang', 'I'), ('asia', 'I'), ('mega', 'I'), ('mas', 'O'), ('sampai', 'O'), ('setengah', 'O'), ('jam', 'O'), ('biasanya', 'O'), ('terjadi', 'O'), ('di', 'O'), ('hari', 'O'), ('senin', 'O')]
# 246
# [('Bagus-bagus', 'O'), ('teller', 'O'), ('bca', 'O'), ('pelayanannya', 'O')]
# [('Bagus-bagus', 'O'), ('teller', 'B'), ('bca', 'I'), ('pelayanannya', 'B')]
# 247
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-8a1376f0ea6d> in <module>()
#       2 while True:
#       3     print(i)
# ----> 4     print(test_doc[i])
#       5     print(test_pred[i])
#       6     if test_pred[i][0][0] != test_doc[i][0][0]:
#
# IndexError: list index out of range

# %%
len(test_doc)
# Out:
# 247

# %%
test_pred[-1]
# Out:
# [('Bagus-bagus', 'O'), ('teller', 'B'), ('bca', 'I'), ('pelayanannya', 'B')]

# %%
labels = []
for sentence in test_pred:
    sent_label = []
    for w in sentence:
        sent_label.append(w[1])
    labels.append(sent_label)

# %%
import csv 
    
# field names 
fields = ['index', 'label'] 
    
# data rows of csv file 
rows = [[i, str(e)] for i, e in enumerate(labels)] 
print(rows)
    
# name of csv file 
filename = "pred.txt"
    
# writing to csv file 
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
    csvwriter.writerow(fields) 

    # writing the data rows 
    csvwriter.writerows(rows)
# Out:
# [[0, "['O', 'B', 'I', 'O', 'O', 'B', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'B', 'I', 'O']"], [1, "['O', 'O', 'O', 'O', 'O', 'I', 'I', 'O', 'B', 'B', 'O', 'B', 'O', 'O', 'O', 'B', 'B', 'O', 'B', 'O', 'O', 'B', 'I']"], [2, "['O', 'O', 'B', 'I', 'I', 'O', 'O', 'O', 'B', 'B', 'O', 'O', 'B', 'I']"], [3, "['O', 'B', 'O', 'B', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'B', 'I']"], [4, "['O', 'O', 'B', 'B', 'B', 'O', 'B', 'I', 'O', 'B', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'B', 'I']"], [5, "['B', 'B', 'I', 'O', 'B', 'O', 'B', 'O', 'O', 'B', 'I', 'O', 'O', 'O', 'B', 'O', 'B', 'I', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'O', 'B', 'B']"], [6, "['O', 'O', 'O', 'O', 'B', 'B', 'O', 'B', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'B', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B']"], [7, "['O', 'O', 'O', 'O', 'O', 'B', 'B', 'O', 'B', 'B', 'I', 'O', 'B', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'O', 'O']"], [8, "['B', 'B', 'I', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'I']"], [9, "['B', 'I', 'B', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O']"], [10, "['O', 'B', 'O', 'B', 'B', 'I', 'O', 'O', 'B', 'I', 'I', 'B', 'O', 'O', 'O', 'B', 'O', 'B', 'O', 'O']"], [11, "['O', 'B', 'I', 'B', 'I', 'O', 'B', 'I', 'O', 'O', 'O', 'B']"], [12, "['O', 'O', 'O', 'O', 'O', 'B', 'B', 'I', 'O', 'B', 'B', 'O', 'I']"], [13, "['O', 'B', 'O', 'O', 'B', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'I', 'O']"], [14, "['O', 'O', 'O', 'B', 'B', 'O', 'B', 'I', 'O', 'B', 'B', 'I']"], [15, "['O', 'O', 'B', 'I', 'I', 'B', 'O', 'B', 'I', 'O', 'B', 'I', 'O', 'O', 'O', 'B', 'O', 'B']"], [16, "['B', 'O', 'B', 'O', 'B', 'B', 'B', 'O', 'B', 'O', 'B', 'B', 'O']"], [17, "['O', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'O', 'B', 'O', 'I', 'O', 'O']"], [18, "['O', 'O', 'B', 'B', 'O', 'B', 'I', 'O', 'O', 'B', 'O', 'B']"], [19, "['O', 'B', 'I', 'O', 'B', 'O', 'O', 'O', 'B', 'O']"], [20, "['B', 'I', 'O', 'O', 'O', 'O', 'O', 'I', 'O', 'B', 'O', 'O']"], [21, "['O', 'O', 'O', 'B', 'O', 'O', 'B', 'O', 'B', 'O', 'I', 'O', 'O', 'O', 'O', 'B', 'I', 'I', 'O', 'B', 'O']"], [22, "['O', 'B', 'B', 'I', 'I', 'I', 'O', 'B', 'B', 'I', 'O']"], [23, "['O', 'O', 'O', 'B', 'B', 'O', 'O', 'B', 'B', 'O', 'B', 'O', 'B']"], [24, "['B', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'O', 'B']"], [25, "['B', 'B', 'B', 'I', 'O', 'B', 'B', 'O', 'B']"], [26, "['B', 'O', 'B', 'O', 'O', 'B', 'I', 'O', 'O', 'B']"], [27, "['B', 'B', 'I', 'B', 'O', 'B', 'B']"], [28, "['B', 'B', 'B', 'I', 'O', 'B', 'I', 'O', 'O', 'O', 'O']"], [29, "['O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'B', 'O', 'I', 'B', 'B', 'O', 'O']"], [30, "['O', 'O', 'B', 'B', 'O', 'O', 'O', 'B', 'B', 'I', 'O', 'O', 'O', 'B']"], [31, "['B', 'B', 'B', 'I', 'O', 'B', 'I', 'O', 'O', 'O', 'O']"], [32, "['B', 'B', 'B', 'B', 'O', 'B', 'I', 'O', 'O', 'O', 'O']"], [33, "['O', 'O', 'O', 'B', 'O', 'B', 'I']"], [34, "['B', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'O', 'B']"], [35, "['O', 'O', 'O', 'B', 'O', 'O', 'O', 'B', 'I', 'O', 'B', 'O', 'O', 'O', 'B', 'I', 'B']"], [36, "['B', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'B', 'O', 'O', 'B']"], [37, "['O', 'O', 'O', 'O', 'B', 'O', 'B', 'I', 'O', 'B', 'O']"], [38, "['B', 'B', 'I']"], [39, "['O', 'B', 'B', 'B', 'I', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'I']"], [40, "['O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', 'B', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'B', 'I', 'B', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']"], [41, "['B', 'I', 'B', 'O', 'O', 'B', 'I', 'O', 'B', 'B', 'B']"], [42, "['B', 'O', 'O', 'B', 'O', 'O', 'B', 'B']"], [43, "['B', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'B', 'B', 'B']"], [44, "['B', 'O', 'O', 'O', 'O', 'B', 'B', 'I', 'O', 'O', 'B']"], ...
